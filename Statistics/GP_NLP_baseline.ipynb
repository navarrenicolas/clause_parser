# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install benepar
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# Collecting benepar
#   Downloading benepar-0.2.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.10/dist-packages (from benepar) (3.8.1)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.10/dist-packages (from benepar) (3.6.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from benepar) (2.1.0+cu121)
# Collecting torch-struct>=0.5 (from benepar)
#   Downloading torch_struct-0.5-py3-none-any.whl (34 kB)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.10/dist-packages (from benepar) (0.15.0)
# Requirement already satisfied: transformers[tokenizers,torch]>=4.2.2 in /usr/local/lib/python3.10/dist-packages (from benepar) (4.35.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from benepar) (3.20.3)
# Collecting sentencepiece>=0.1.91 (from benepar)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (4.66.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (6.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.3.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.9.4->benepar) (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (2.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.4.1)
# Collecting accelerate>=0.20.3 (from transformers[tokenizers,torch]>=4.2.2->benepar)
#   Downloading accelerate-0.26.1-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.0.9->benepar) (0.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.0.9->benepar) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->benepar) (1.3.0)
# Building wheels for collected packages: benepar
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37624 sha256=33e1b5f4da967f38f69fa7fa60171a0e42e6ec83f2b179d4e796054c3da1d8b2
#   Stored in directory: /root/.cache/pip/wheels/8d/4d/c1/a5af726368d5dbaaaa0b2dd36ed39b9da8cec46279a49bd6db
# Successfully built benepar
# Installing collected packages: sentencepiece, torch-struct, accelerate, benepar
# Successfully installed accelerate-0.26.1 benepar-0.2.0 sentencepiece-0.1.99 torch-struct-0.5
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)
# 2024-01-15 01:31:53.329173: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-15 01:31:53.329303: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-15 01:31:53.333275: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-15 01:31:53.355283: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-15 01:31:54.938901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-lg==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.6.0/en_core_web_lg-3.6.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 849.2 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-lg==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import benepar, spacy
import os
import re
from typing import List, Set, Dict, Tuple
from spacy import displacy
from spacy.matcher import Matcher
from spacy.tokenizer import Tokenizer
import warnings
import csv
import pandas as pd
import math

warnings.filterwarnings('ignore')

# %%
benepar.download('benepar_en3')
nlp = spacy.load('en_core_web_lg')

if spacy.__version__.startswith('2'):
    nlp.add_pipe(benepar.BeneparComponent("benepar_en3"))
else:
    nlp.add_pipe("benepar", config={"model": "benepar_en3"})
# Out:
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
decl_samples = open('/content/drive/My Drive/samples/finite declarative clauses.txt').read().replace('\n', ' ')
pol_samples = open('/content/drive/My Drive/samples/finite polar interrogative clauses.txt').read().replace('\n', ' ')
const_samples = open('/content/drive/My Drive/samples/finite constituent interrogative clauses.txt').read().replace('\n', ' ')
alt_samples = open('/content/drive/My Drive/samples/finite alternative interrogative clauses.txt').read().replace('\n', ' ')
adv_samples = open('/content/drive/My Drive/samples/adversarial.txt').read().replace('\n', ' ')
#common_crawl_sample = open('/content/drive/My Drive/samples/cc_en_head-0000_sample.txt').read().replace('\n', ' ')

# %%
print(adv_samples)
# Out:
# ﻿I have every confidence that you’ll do well. It’s true whether you like it or not. I’ll be happy whether or not it’s true. Regardless of whether or not you’ve won, I’m proud. John is happy whichever student won the race. John told Mary, who is a good listener. John spilt what Mary was cooking. Al took what Bo left behind. Al is happy which is the best. I ate when you were out.

# %%
all_examples = decl_samples + " " + pol_samples + " " + const_samples + " " + alt_samples + " " + adv_samples
doc5 = nlp(all_examples)
#for sent in doc5.sents:
#  pos = [token.pos_ for token in sent]
#  print(sent, pos)
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.

# %%
#verb matching - the baseline heuristics
verb_matcher = Matcher(nlp.vocab)

verb_patterns = []
SINGLES = ["believe", "think", "know", "wonder", "hope", "fear", "like", "regret", "see", "ask", "say", "tell", "check", "decide", "determine", "consider"]
DOUBLES = ["certain", "happy", "curious"]

for sing in SINGLES:
  pattern = [{"LEMMA": sing, "POS": "VERB"}]
  verb_patterns.append(pattern)

for doub in DOUBLES:
  pattern = [{"LEMMA": "be", "POS": "AUX"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}, {"LEMMA": doub}]
  verb_patterns.append(pattern)

verb_matcher.add("embedding_verb", verb_patterns)

#clause matching
clause_matcher = Matcher(nlp.vocab)
pattern_d = [{"TEXT": "that", "POS": "SCONJ"}]
clause_matcher.add("declarative", [pattern_d])

pattern_i1 = [{"TEXT": "whether", "POS": "SCONJ"}]
clause_matcher.add("polar", [pattern_i1])

pattern_c1 = [{"TEXT": "who"}]
pattern_c2 = [{"TEXT": "what"}]
pattern_c3 = [{"TEXT": "when"}]
pattern_c4 = [{"TEXT": "where"}]
pattern_c5 = [{"TEXT": "why"}]
pattern_c6 = [{"TEXT": "how"}]
pattern_c7 = [{"TEXT": "which"}]
clause_matcher.add("constituent", [pattern_c1, pattern_c2, pattern_c3, pattern_c4, pattern_c5, pattern_c6, pattern_c7])


#this function takes nlp("concatenated sentences").sents as input and prints annotations
def get_baseline(sentences, print_negs = False):
  embeddings = []

  for sent in sentences:
    embedded_clauses = []

    #get embedding predicates
    verb_matches = verb_matcher(sent)
    for match_id, start, end in verb_matches:
        emb = dict.fromkeys(["sentence", "predicate", "clause", "type"])
        emb["predicate"] = dict.fromkeys(["token", "pos", "preposition"])

        #default values for sentence and for predicate annotation
        emb["sentence"] = sent.text
        emb["predicate"]["token"] = sent[start].text
        emb["predicate"]["pos"] = "VERB"

        #doubles values for predicate annotation
        if sent[end-1].text in ["happy", "certain", "curious"]:
          emb["predicate"]["pos"] = "ADJ"
          emb["predicate"]["token"] = sent[end-1].text

        #edge cases where there is a preposition, adverb, pronoun, or noun between the verb and the clause
        if sent[end].pos_ == "ADP":
          emb["predicate"]["preposition"] = sent[end].text
          end += 1

        if sent[end].pos_ in ["ADV", "PRON", "PROPN"] and (not end < len(sent)) and (sent[end+1].pos_ in ["SCONJ", "PRON"]):
          end += 1

        #get the potential clause
        clause = sent[end:-1]
        emb["clause"] = clause.text

        #find clause type
        clause_matches = clause_matcher(clause)
        clause_pos = [token.pos_ for token in clause]

        for match_id, start, end in clause_matches:
          clause_type = nlp.vocab.strings[match_id]
          emb["type"] = clause_type

          #separate polars from alternatives
          if clause_type == "polar":
            if (" or " in clause.text) and not (" or not " in clause.text) and not (" or not." in sent[end:].text):
              emb["type"] = "alternative"

          break

        #type declaraties without marks
        if clause_matches == [] and (clause_pos.count("VERB") ==1 or clause_pos.count("AUX") ==1):
          emb["type"] = "declarative"

        #if it was a genuine embedded clause add to the sentence's set of annotations
        if emb["type"] != None:
          embedded_clauses.append(emb)

    ##tn or fn
    #if embedded_clauses == []:
    #  print("\n", sent, [token.lemma_ for token in sent], "\n")

    #tps and fps
    #else:
    if embedded_clauses != []:
      print(embedded_clauses)
      embeddings.append(embedded_clauses)

    elif print_negs == True:
      embeddings.append([{'sentence': sent}])
      print([{'sentence': sent}])

  return embeddings

# %%
#get output file for samples
ex = get_baseline(doc5.sents, print_negs=True)

with open('/content/drive/My Drive/samples/baseline_samples.csv', 'w', newline='') as csvfile:
  bwriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  bwriter.writerow(["line_number", "sents", "has_clause", "type",	"predicate"])
  for i, s in enumerate(ex):
    first = s[0]
    if len(first.keys()) > 1:
      bwriter.writerow([i+1, '"' + str(first['sentence']) + '"', 1, first['type'], first['predicate']['token']])
    else:
      bwriter.writerow([i+1, '"' + str(first['sentence']) + '"', 0])
# Out:
# [{'sentence': 'John believes that the movie was unpleasant.', 'predicate': {'token': 'believes', 'pos': 'VERB', 'preposition': None}, 'clause': 'that the movie was unpleasant', 'type': 'declarative'}]
# [{'sentence': 'John believes the movie was unpleasant.', 'predicate': {'token': 'believes', 'pos': 'VERB', 'preposition': None}, 'clause': 'the movie was unpleasant', 'type': 'declarative'}]
# [{'sentence': 'John saw that Mary didn’t like the movie.', 'predicate': {'token': 'saw', 'pos': 'VERB', 'preposition': None}, 'clause': 'that Mary didn’t like the movie', 'type': 'declarative'}]
# [{'sentence': 'I hoped you’d like the movie.', 'predicate': {'token': 'hoped', 'pos': 'VERB', 'preposition': None}, 'clause': 'you’d like the movie', 'type': 'declarative'}]
# [{'sentence': 'John was happy that the movie was good.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': None}, 'clause': 'that the movie was good', 'type': 'declarative'}]
# [{'sentence': 'John was happy the movie was good.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': None}, 'clause': 'the movie was good', 'type': 'declarative'}]
# [{'sentence': Does John like that Mary did not like the movie?}]
# [{'sentence': 'The woman with the blue shirt said that the movie was unrealistic.  ', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'that the movie was unrealistic.', 'type': 'declarative'}]
# [{'sentence': 'John thinks frequently that Mary likes movies.', 'predicate': {'token': 'thinks', 'pos': 'VERB', 'preposition': None}, 'clause': 'frequently that Mary likes movies', 'type': 'declarative'}]
# [{'sentence': 'John wondered that Mary did not like the movie.', 'predicate': {'token': 'wondered', 'pos': 'VERB', 'preposition': None}, 'clause': 'that Mary did not like the movie', 'type': 'declarative'}]
# [{'sentence': '\ufeffJohn wonders whether Mary made it to class.', 'predicate': {'token': 'wonders', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary made it to class', 'type': 'polar'}]
# [{'sentence': 'John wonders whether Mary liked the movie or not.', 'predicate': {'token': 'wonders', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary liked the movie or not', 'type': 'polar'}]
# [{'sentence': 'John asked Mary whether she liked the movie.', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'Mary whether she liked the movie', 'type': 'polar'}]
# [{'sentence': 'John thought about whether Mary would like the movie or not.', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': 'about'}, 'clause': 'whether Mary would like the movie or not', 'type': 'polar'}]
# [{'sentence': 'Have you thought yet whether or not you’ll go?', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': None}, 'clause': 'yet whether or not you’ll go', 'type': 'polar'}]
# [{'sentence': 'John asked whether Mary came to the theatre and then left.', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary came to the theatre and then left', 'type': 'polar'}]
# [{'sentence': 'John was curious about whether or not Mary liked the movie, so he asked her.', 'predicate': {'token': 'curious', 'pos': 'ADJ', 'preposition': 'about'}, 'clause': 'whether or not Mary liked the movie, so he asked her', 'type': 'polar'}, {'sentence': 'John was curious about whether or not Mary liked the movie, so he asked her.', 'predicate': {'token': 'liked', 'pos': 'VERB', 'preposition': None}, 'clause': 'the movie, so he asked her', 'type': 'declarative'}]
# [{'sentence': 'John is curious whether it will rain.', 'predicate': {'token': 'curious', 'pos': 'ADJ', 'preposition': None}, 'clause': 'whether it will rain', 'type': 'polar'}]
# [{'sentence': 'John would have thought about whether he liked the movie, but decided not to.', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': 'about'}, 'clause': 'whether he liked the movie, but decided not to', 'type': 'polar'}, {'sentence': 'John would have thought about whether he liked the movie, but decided not to.', 'predicate': {'token': 'liked', 'pos': 'VERB', 'preposition': None}, 'clause': 'the movie, but decided not to', 'type': 'declarative'}]
# [{'sentence': 'Do you know whether the assignment is due tomorrow?', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether the assignment is due tomorrow', 'type': 'polar'}]
# [{'sentence': '\ufeffJohn knows what movie Mary picked.', 'predicate': {'token': 'knows', 'pos': 'VERB', 'preposition': None}, 'clause': 'what movie Mary picked', 'type': 'constituent'}]
# [{'sentence': 'I saw which room the professor reserved, but I didn’t write it down.', 'predicate': {'token': 'saw', 'pos': 'VERB', 'preposition': None}, 'clause': 'which room the professor reserved, but I didn’t write it down', 'type': 'constituent'}]
# [{'sentence': 'John asked where Mary wanted it, and she picked the living room.', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'where Mary wanted it, and she picked the living room', 'type': 'constituent'}]
# [{'sentence': 'Do you know which part of the sentence is most relevant for the derivation?', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'which part of the sentence is most relevant for the derivation', 'type': 'constituent'}]
# [{'sentence': 'John is happy about who won the race.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': 'about'}, 'clause': 'who won the race', 'type': 'constituent'}]
# [{'sentence': 'It’s not easy to decide why that student won the race.', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': 'why that student won the race', 'type': 'constituent'}]
# [{'sentence': 'John is not certain when she won the highest score.', 'predicate': {'token': 'certain', 'pos': 'ADJ', 'preposition': None}, 'clause': 'when she won the highest score', 'type': 'constituent'}]
# [{'sentence': 'I wonder often how one of them is most likely to win the race.', 'predicate': {'token': 'wonder', 'pos': 'VERB', 'preposition': None}, 'clause': 'often how one of them is most likely to win the race', 'type': 'constituent'}]
# [{'sentence': 'John knows how his friends are to win the race and why.', 'predicate': {'token': 'knows', 'pos': 'VERB', 'preposition': None}, 'clause': 'how his friends are to win the race and why', 'type': 'constituent'}]
# [{'sentence': 'I already said where I think it should go.', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'where I think it should go', 'type': 'constituent'}, {'sentence': 'I already said where I think it should go.', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'it should go', 'type': 'declarative'}]
# [{'sentence': '\ufeffJohn wondered whether Mary had chosen the comedy movie or the action movie.', 'predicate': {'token': 'wondered', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary had chosen the comedy movie or the action movie', 'type': 'alternative'}]
# [{'sentence': 'I’ll check whether it was assigned yesterday or the day before.', 'predicate': {'token': 'check', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether it was assigned yesterday or the day before', 'type': 'alternative'}]
# [{'sentence': 'We can determine whether it’s an apple, oak, or cherry tree.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether it’s an apple, oak, or cherry tree', 'type': 'alternative'}]
# [{'sentence': 'John wondered whether Mary was taller or shorter than Anne.', 'predicate': {'token': 'wondered', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary was taller or shorter than Anne', 'type': 'alternative'}]
# [{'sentence': 'How many ways can we ask whether you preferred the first, the second, or the third option?', 'predicate': {'token': 'ask', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether you preferred the first, the second, or the third option', 'type': 'alternative'}]
# [{'sentence': 'John asked himself frequently whether he should stay or he should go.', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'himself frequently whether he should stay or he should go', 'type': 'alternative'}]
# [{'sentence': 'Tell me whether you’ll go for the apple, the pear or the orange.', 'predicate': {'token': 'Tell', 'pos': 'VERB', 'preposition': None}, 'clause': 'me whether you’ll go for the apple, the pear or the orange', 'type': 'alternative'}]
# [{'sentence': 'It’s getting late, and I’m wondering whether Mary is working or whether she is taking a break.', 'predicate': {'token': 'wondering', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether Mary is working or whether she is taking a break', 'type': 'alternative'}]
# [{'sentence': 'John is considering whether it’s better to keep it to himself or to tell Mary about it.', 'predicate': {'token': 'considering', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether it’s better to keep it to himself or to tell Mary about it', 'type': 'alternative'}]
# [{'sentence': I’m not certain whether Mary read War and Peace or Anna Karenina.}]
# [{'sentence': ﻿I have every confidence that you’ll do well.}]
# [{'sentence': It’s true whether you like it or not.}]
# [{'sentence': 'I’ll be happy whether or not it’s true.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': None}, 'clause': 'whether or not it’s true', 'type': 'polar'}]
# [{'sentence': Regardless of whether or not you’ve won, I’m proud.}]
# [{'sentence': 'John is happy whichever student won the race.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': None}, 'clause': 'whichever student won the race', 'type': 'declarative'}]
# [{'sentence': 'John told Mary, who is a good listener.', 'predicate': {'token': 'told', 'pos': 'VERB', 'preposition': None}, 'clause': 'Mary, who is a good listener', 'type': 'constituent'}]
# [{'sentence': John spilt what Mary was cooking.}]
# [{'sentence': Al took what Bo left behind.}]
# [{'sentence': 'Al is happy which is the best.', 'predicate': {'token': 'happy', 'pos': 'ADJ', 'preposition': None}, 'clause': 'which is the best', 'type': 'constituent'}]
# [{'sentence': I ate when you were out.}]

# %%
#sets - natural

decl_gold = pd.read_csv('/content/drive/My Drive/samples/declarative_golden_set_checked.csv')
pol_gold = pd.read_csv('/content/drive/My Drive/samples/polar_golden_set_checked.csv')
const_gold = pd.read_csv('/content/drive/My Drive/samples/constituent_golden_set_checked.csv')
alt_gold = pd.read_csv('/content/drive/My Drive/samples/alternative_golden_set_checked.csv')
adv_gold = pd.read_csv('/content/drive/My Drive/samples/adversarials_golden_set_checked.csv')

golds = [decl_gold, pol_gold, const_gold, alt_gold, adv_gold]

# %%
#sets - samples
out_samp = pd.read_csv('/content/drive/My Drive/samples/baseline_samples.csv')

dec_samp = pd.read_csv('/content/drive/My Drive/samples/golden_sample_declarative.csv')
pol_samp = pd.read_csv('/content/drive/My Drive/samples/golden_sample_polar.csv')
con_samp = pd.read_csv('/content/drive/My Drive/samples/golden_sample_constituent.csv')
alt_samp = pd.read_csv('/content/drive/My Drive/samples/golden_sample_alternative.csv')
adv_samp = pd.read_csv('/content/drive/My Drive/samples/golden_sample_adversarial.csv')

samples = [dec_samp, pol_samp, con_samp, alt_samp, adv_samp]

# %%
#get output files for golden sets

for i, typ in enumerate(['declarative', 'polar', 'constituent', 'alternative', 'adversarial']):
  filepath = '/content/drive/My Drive/samples/' + 'baseline_' + typ + '_golden.csv'
  line_numbers = list(golds[i]['line_number'])

  with open(filepath, 'w', newline='') as csvfile:
    bwriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    bwriter.writerow(["line_number", "sents", "has_clause", "type",	"predicate"])

    for j, sen in enumerate(list(golds[i]['sents'])):
      sen_doc = nlp(sen)
      out = get_baseline(sen_doc.sents, print_negs=True)
      first = out[0][0]

      if len(first.keys()) > 1:
        bwriter.writerow([line_numbers[j], '"' + str(first['sentence']) + '"', 1, first['type'], first['predicate']['token']])

      else:
        bwriter.writerow([line_numbers[j], '"' + str(first['sentence']) + '"', 0])
# Out:
# [{'sentence': Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz'}]
# [{'sentence': Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.}]
# [{'sentence': 'I have always loved fashion and believe that it plays an integral role in self expression', 'predicate': {'token': 'believe', 'pos': 'VERB', 'preposition': None}, 'clause': 'that it plays an integral role in self', 'type': 'declarative'}]
# [{'sentence': Being a Conroe and Woodlands Family Photographer, I find that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions)}]
# [{'sentence': 'I can honestly say that that is precisely what happened on this day', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that that is precisely what happened on this', 'type': 'declarative'}]
# [{'sentence': 'I have decided that I want her to be my pen pal and take it back old school', 'predicate': {'token': 'decided', 'pos': 'VERB', 'preposition': None}, 'clause': 'that I want her to be my pen pal and take it back old', 'type': 'declarative'}]
# [{'sentence': They were up for something different and an adventure, so I felt it was a great opportunity to shoot in!}]
# [{'sentence': Becca also wore dresses from my The Woodlands Photographer studio and it was perfect.}]
# [{'sentence': I am also praying that everyone who flooded is doing ok and things are getting back to normal!}]
# [{'sentence': Up next on the blog is this sweet The Woodlands Newborn Studio session.}]
# [{'sentence': I also should mention that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session.}]
# [{'sentence': 'This is not to say that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three', 'type': 'declarative'}]
# [{'sentence': When we laid our foundation stone in Denver, CO 80211 almost 10 years ago, we realized that the people of the city have been desperately missing the services of a professional locksmith company}]
# [{'sentence': 'For anyone following Tiny Tim’s adventures, we know that he lives with his mum and has never met his real dad', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'that he lives with his mum and has never met his real', 'type': 'declarative'}]
# [{'sentence': "@avoto hm, I don't think that it's a good idea", 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': "that it's a good", 'type': 'declarative'}]
# [{'sentence': '@PaulMaly_twitter I was thinking that there can be more than one version where one is is the Ractive component file as per the official spec', 'predicate': {'token': 'thinking', 'pos': 'VERB', 'preposition': None}, 'clause': 'that there can be more than one version where one is is the Ractive component file as per the official', 'type': 'declarative'}]
# [{'sentence': 'I think the components should be written so that they could work without any compilation at least in one environment', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'the components should be written so that they could work without any compilation at least in one', 'type': 'declarative'}]
# [{'sentence': 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and,', 'type': 'declarative'}]
# [{'sentence': Here I argue that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed}]
# [{'sentence': 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'predicate': {'token': 'believe', 'pos': 'VERB', 'preposition': None}, 'clause': 'that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of', 'type': 'declarative'}]
# [{'sentence': Yet, if we deny that Jones’ life has any real meaning because his pain outweighs his enjoyment of life then his worth is reduced to the sum total of the pain or the pleasure he is experiencing}]
# [{'sentence': Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)}]
# [{'sentence': It is to admit that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them.}]
# [{'sentence': However, defining mercy solely as relationship might indicate that euthanasia is not incompatible with mercy}]
# [{'sentence': However, to accept this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death}]
# [{'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': {'token': 'Thinking', 'pos': 'VERB', 'preposition': 'about'}, 'clause': 'Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love', 'type': 'declarative'}, {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': {'token': 'see', 'pos': 'VERB', 'preposition': None}, 'clause': 'it in the light of someone’s love', 'type': 'declarative'}]
# [{'sentence': 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'predicate': {'token': 'seeing', 'pos': 'VERB', 'preposition': None}, 'clause': 'that Jones is loved, we realise Jones to be a person with inherent', 'type': 'declarative'}]
# [{'sentence': 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'predicate': {'token': 'saying', 'pos': 'VERB', 'preposition': None}, 'clause': 'that new car sales took a nosedive in September, signaling economic distress could be just around the', 'type': 'declarative'}]
# [{'sentence': News BREAKING:}]
# [{'sentence': HHA owner Jon Kelly has revealed he was sacked on Monday as administrators Ferrier Hodgson announced the business was in voluntary administration.}]
# [{'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': {'token': 'like', 'pos': 'VERB', 'preposition': None}, 'clause': "to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013", 'type': 'declarative'}, {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': "that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013", 'type': 'declarative'}, {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013', 'type': 'constituent'}]
# [{'sentence': If you are looking for a walk-in closest for the biggest wardrobe this home has it for the icing on the cake!Did I forget to mention the home has 3 zone heat and Air conditioning on 1.8 acres of property on a no thruway street}]
# [{'sentence': Ready-made Greens can be useful for mixing other colours too, we’re not suggesting you should chuck them out!}]
# [{'sentence': 'You will see that small differences in the amount of black can make a big difference to the colour you make.', 'predicate': {'token': 'see', 'pos': 'VERB', 'preposition': None}, 'clause': 'that small differences in the amount of black can make a big difference to the colour you make', 'type': 'declarative'}]
# [{'sentence': 'I have so many things I want to write about I fear I’m bursting at the seams', 'predicate': {'token': 'fear', 'pos': 'VERB', 'preposition': None}, 'clause': 'I’m bursting at the', 'type': 'declarative'}]
# [{'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??”', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??', 'type': 'declarative'}, {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??”', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': 'to'}, 'clause': 'me “Did YOU HEAR THAT??', 'type': 'declarative'}]
# [{'sentence': And I look at C’s dad and he’s saying the same}]
# [{'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': None}, 'clause': 'he could', 'type': 'declarative'}]
# [{'sentence': He’s also told me he wants to try out for football next year}]
# [{'sentence': 'I don’t think I’m ready for the pain that’s going to go along with the teenage years', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'I’m ready for the pain that’s going to go along with the teenage', 'type': 'declarative'}]
# [{'sentence': To any studio execs who may be reading this: I can't guarantee that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers.}]
# [{'sentence': I realize this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie}]
# [{'sentence': Just to reiterate that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing}]
# [{'sentence': And that Jamie Schler article…I wish I were as fiery}]
# [{'sentence': 'I think not letting one’s computer get in the way of real life is sound advice', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'not letting one’s computer get in the way of real life is sound', 'type': 'declarative'}]
# [{'sentence': 'Later in the article, Portnoy says that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things.', 'predicate': {'token': 'says', 'pos': 'VERB', 'preposition': None}, 'clause': 'that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things', 'type': 'declarative'}]
# [{'sentence': No matter how ridiculous the jokes, or over the top the take, it was understood by most that we are just here to make people laugh.}]
# [{'sentence': 'On that count, he knows all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on.', 'predicate': {'token': 'knows', 'pos': 'VERB', 'preposition': None}, 'clause': 'all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on', 'type': 'declarative'}]
# [{'sentence': and I guess they smelt well.}]
# [{'sentence': 'Michelle Obama says her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'predicate': {'token': 'says', 'pos': 'VERB', 'preposition': None}, 'clause': 'her family has decided to make a Portuguese Water Dog the first dog around the Obama White', 'type': 'declarative'}, {'sentence': 'Michelle Obama says her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'predicate': {'token': 'decided', 'pos': 'VERB', 'preposition': None}, 'clause': 'to make a Portuguese Water Dog the first dog around the Obama White', 'type': 'declarative'}]
# [{'sentence': 'The First Lady told People Magazine the Obamas are searching animal rescues for that particular breed.', 'predicate': {'token': 'told', 'pos': 'VERB', 'preposition': None}, 'clause': 'People Magazine the Obamas are searching animal rescues for that particular breed', 'type': 'declarative'}]
# [{'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': {'token': 'says', 'pos': 'VERB', 'preposition': None}, 'clause': 'she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}, {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': {'token': 'hopes', 'pos': 'VERB', 'preposition': None}, 'clause': 'the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}]
# [{'sentence': 'Obama says she learned from Sen', 'predicate': {'token': 'says', 'pos': 'VERB', 'preposition': None}, 'clause': 'she learned from', 'type': 'declarative'}]
# [{'sentence': "I know that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': "that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for", 'type': 'declarative'}]
# [{'sentence': 'Is it accurate to say that you are a specialist in a particular field?', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that you are a specialist in a particular field', 'type': 'declarative'}]
# [{'sentence': From movement, form, cooking, to DIY, and expulsion administrations, on the off chance that you realize how to accomplish something especially well, why not tell the world through a blog or video blog?}]
# [{'sentence': All you will require is a PC and a decent quality camera}]
# [{'sentence': 'I know you have made a planned to leave your 9-to-5 job', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'you have made a planned to leave your 9-to-5', 'type': 'declarative'}]
# [{'sentence': 'Plus, I don’t think I barely snacked at all', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'I barely snacked at', 'type': 'declarative'}]
# [{'sentence': I too have been upping the healthy fats in my diet an have definitely noticed that I can last for up to 6 hours without feeling hunger pains!!}]
# [{'sentence': 'Nevertheless, its really hard for me to get past the “fat is bad” hurdle because everyone and everything is telling us to eat no or less fat', 'predicate': {'token': 'telling', 'pos': 'VERB', 'preposition': None}, 'clause': 'us to eat no or less', 'type': 'declarative'}]
# [{'sentence': 'Some people say that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive tract', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive', 'type': 'declarative'}]
# [{'sentence': 'Do you think the 01753476428 was a harass phone number?', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'the 01753476428 was a harass phone number', 'type': 'declarative'}]
# [{'sentence': NationalLedger.com reports that Christina Aguilera risked re-igniting her feud with Britney Spears by a comment made on her wedding day}]
# [{'sentence': Christina’s rep denies she made any comment however.}]
# [{'sentence': In this sense, Mignolo argues that while modernity is not strictly a European phenomenon, its rhetoric -as Dussel argues- is formed by European philosophers, academics and politicians}]
# [{'sentence': Business guests appreciate that our downtown hotel's location in Lexington, KY is close to IBM, PNC Bank, Fifth Third Bank, Ashland and UPS}]
# [{'sentence': 'AEPi is proud to say that we are one of the loudest Jewish voices on campus', 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'that we are one of the loudest Jewish voices on', 'type': 'declarative'}]
# [{'sentence': On January 31, 2015, The Sacramento Bee reported that the AEPi building in Davis had been tagged with two large swastikas}]
# [{'sentence': 'I think this is just too cool for school!!!!!', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'this is just too cool for school!!!!', 'type': 'declarative'}]
# [{'sentence': With this issue, they said they thought it was a virus and would have it running the next day}]
# [{'sentence': Click said that would not be an issue.}]
# [{'sentence': 'I checked in with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'predicate': {'token': 'checked', 'pos': 'VERB', 'preposition': 'in'}, 'clause': 'with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final', 'type': 'constituent'}, {'sentence': 'I checked in with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'predicate': {'token': 'told', 'pos': 'VERB', 'preposition': None}, 'clause': 'it would be one more day - they were doing some final', 'type': 'declarative'}]
# [{'sentence': The next day I learned that they had not put any real time evaluating my laptop and would require a couple more days}]
# [{'sentence': After two more days they said they needed to repair the backlight before trying to determine the other problem}]
# [{'sentence': ​Digging a little deeper, we managed to find out that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues.}]
# [{'sentence': "It's interesting to know that Wayne was a co-founder of the Humane Society Legislative Fund", 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'that Wayne was a co-founder of the Humane Society Legislative', 'type': 'declarative'}]
# [{'sentence': At Radon Fan Guys, we understand that you have to stay within your price range and save cash everywhere you're able to}]
# [{'sentence': We use the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project}]
# [{'sentence': Then he shocked her by declaring that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria}]
# [{'sentence': The Founders Scholarship was created in 2010 by fifteen individuals or couples to ensure that all graduating Mackinac Island students have an opportunity for a multi-year scholarship award}]
# [{'sentence': The Local Government Association estimates that by 2025, the funding gap will grow to £3bn for children’s social care alone.}]
# [{'sentence': 'We are told that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection services', 'predicate': {'token': 'told', 'pos': 'VERB', 'preposition': None}, 'clause': 'that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection', 'type': 'declarative'}]
# [{'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': {'token': 'saying', 'pos': 'VERB', 'preposition': None}, 'clause': 'that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the', 'type': 'declarative'}, {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': {'token': 'see', 'pos': 'VERB', 'preposition': None}, 'clause': 'how this could be the', 'type': 'constituent'}]
# [{'sentence': 'But the government is already backing down on this claim, with Jo Farrar, director general to the Ministry of Housing, Communities and Local Government, telling the public accounts committee this week that they do not expect these funds to buy additional capacity', 'predicate': {'token': 'telling', 'pos': 'VERB', 'preposition': None}, 'clause': 'the public accounts committee this week that they do not expect these funds to buy additional', 'type': 'declarative'}]
# [{'sentence': 'She believes this map will help students complete their homework on time.', 'predicate': {'token': 'believes', 'pos': 'VERB', 'preposition': None}, 'clause': 'this map will help students complete their homework on time', 'type': 'declarative'}]
# [{'sentence': In this criminal complaint, the government claims that Khaalid Adam Abdulkadir made death threats against FBI agents in various Twitter posts}]
# [{'sentence': The government agreed that its informant was responsible for first alerting law enforcement to the Twitter communications, but refused disclosure under the government–informant privilege.}]
# [{'sentence': The court held that Abdulkadir failed to show that the FBI’s confidential informant was material to his defense}]
# [{'sentence': The court noted that the case remains in the pre-indictment stage, and will permit Abdulkadir to renew his motion at a later date}]
# [{'sentence': The sting operation, however, allegedly reveals that our personal data may not be totally secure in the hands of a digital payments giant and that it may have sold it to other third-parties out there}]
# [{'sentence': Please ensure you revisit this page and re–check for any updates/changes before the date of the fixture.}]
# [{'sentence': 'I know these are just models, but we always like to share them with you', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'these are just models, but we always like to share them with', 'type': 'declarative'}, {'sentence': 'I know these are just models, but we always like to share them with you', 'predicate': {'token': 'like', 'pos': 'VERB', 'preposition': None}, 'clause': 'to share them with', 'type': 'declarative'}]
# [{'sentence': Many have been speculating that the announcement is for the long awaited next installment in the Persona series}]
# [{'sentence': You could argue that these elements fall under the category of story, which Persona 3 won anyway, but I feel they are significant enough to make a difference}]
# [{'sentence': This is to inform you that you have been selected for a cash prize of £850,000.00 (Eight hundred and fifty thousand Great British Pounds) from the BMW AUTOMOBILE GROUP e-LOTTERY BONANZA International programs held TODAY Teusday the 6th of MARCH 2007, here in London United Kingdom.}]
# [{'sentence': 'I think that does a good job of summarising my feelings towards friends who drift away over time.', 'predicate': {'token': 'think', 'pos': 'VERB', 'preposition': None}, 'clause': 'that does a good job of summarising my feelings towards friends who drift away over time', 'type': 'declarative'}]
# [{'sentence': "According to the Children's Action Network, nationwide each year 20,000 children age out of the foster care system, but experts say they are still in need of a family as they embark on work and college.", 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'they are still in need of a family as they embark on work and college', 'type': 'declarative'}]
# [{'sentence': Executive producer Brandon Margolis revealed that Fletcher, the hacker who helps Mike and Marcus in both films, would also appear in the show.}]
# [{'sentence': Valentino still loves MotoGP and last year he demonstrated that he still can be competitive}]
# [{'sentence': Maverick Vinales admits he was puzzled by why he was uncompetitive on the second day of Valencia's post-season MotoGP test on Wednesday having topped the times on day one.}]
# [{'sentence': 'Repsol Honda Team Principal Livio Suppo has said that he and Honda aren’t surprised by the pace and performances of new Yamaha recruit Maverick Viñales, but that they are of his team-mate, Valentino Rossi.', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'that he and Honda aren’t surprised by the pace and performances of new Yamaha recruit Maverick Viñales, but that they are of his team-mate, Valentino Rossi', 'type': 'declarative'}]
# [{'sentence': 'Introducing the bill, Law Minister Ravi Shankar Prasad said despite the Supreme Court striking down the practice of talaq-e-biddat (instant triple talaq) as unconstitutional, men were divorcing their wives on flimsy grounds and even via Whatsapp.', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'despite the Supreme Court striking down the practice of talaq-e-biddat (instant triple talaq) as unconstitutional, men were divorcing their wives on flimsy grounds and even via Whatsapp', 'type': 'declarative'}]
# [{'sentence': "Putin, speaking in International Investments Forum in Sochi, said that Russia's inflation rate would be 7 percent this year.", 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': "that Russia's inflation rate would be 7 percent this year", 'type': 'declarative'}]
# [{'sentence': He reminded that in 2009, Russia's GDP dropped by 7.9 percent, inflation reached 9 percent.}]
# [{'sentence': August was the first month since May when industrial output in Russia was above zero and reaches 0.1 percent, thus Nabiullina called August "a good month", admitting that in agricultural sector growth was negative by 9.6 percent.}]
# [{'sentence': i have ensured that the wireless sync is activated on the handhelds as well}]
# [{'sentence': "Firstly, I must say that my comments below are not a criticism of teachers, who work very hard against all the odds, but of education systems that have 'lost their way'", 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': "that my comments below are not a criticism of teachers, who work very hard against all the odds, but of education systems that have 'lost their way", 'type': 'declarative'}]
# [{'sentence': "I believe only the chemistry specialist has the 'depth of knowledge' to enthuse the students, which in turn leads to an increased uptake in the subject.", 'predicate': {'token': 'believe', 'pos': 'VERB', 'preposition': None}, 'clause': "only the chemistry specialist has the 'depth of knowledge' to enthuse the students, which in turn leads to an increased uptake in the subject", 'type': 'constituent'}]
# [{'sentence': '74% thought it was too noisy.', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': None}, 'clause': 'it was too noisy', 'type': 'declarative'}]
# [{'sentence': '81% said the bathroom was dirty.', 'predicate': {'token': 'said', 'pos': 'VERB', 'preposition': None}, 'clause': 'the bathroom was dirty', 'type': 'declarative'}]
# [{'sentence': Everyone is aware that finding someone close to you can be tiring, so we founded our site with three ideas as our goal: we want to make finding locals easy, mobile, and totally free}]
# [{'sentence': 'Simply adjust your settings and know you will find exactly who you want at the ideal time for you.', 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'you will find exactly who you want at the ideal time for you', 'type': 'constituent'}]
# [{'sentence': 'I’ve been blogging for over three years now, mostly as a passion and I have only became more professional in the recent months but never thought I’d end up making up a start a blog tutorial', 'predicate': {'token': 'thought', 'pos': 'VERB', 'preposition': None}, 'clause': 'I’d end up making up a start a blog', 'type': 'declarative'}]
# [{'sentence': That makes me really happy, I know I had a hard time getting a blog up!}]
# [{'sentence': 'Please note you will be billed a year a time, but as you can see, it works out to a very reasonable monthly amount', 'predicate': {'token': 'see', 'pos': 'VERB', 'preposition': None}, 'clause': ', it works out to a very reasonable monthly', 'type': 'declarative'}]
# [{'sentence': Fill in your billing information, confirm that you’ve read the fine print and then click Next.}]
# [{'sentence': I hope my start a blog tutorial has been of help and I look forward to hear your input and also read your new, beautiful blogs}]
# [{'sentence': Irving Azoff Claims YouTube "Pirates" Are "Really Evil"}]
# [{'sentence': Will Someone Explain To The RIAA That SOPA Didn't Pass?}]
# [{'sentence': (Buffalo, NY) – New York State Senator Chris Jacobs announced that he has secured $120,000 in state funding for the twelve branch libraries in the 60th Senate District}]
# [{'sentence': Even his friends aren't sure whether he should come back, leading to a frank discussion of resurrection in the Marvel Universe.}]
# [{'sentence': Thus water placed in a vessel with a shaving of camphor thrown upon it will show whether the vessel is clean or not.}]
# [{'sentence': This inquiry will help the reader understand whether a relationship between Mexican female politicians and policies created against violence exists.}]
# [{'sentence': The Fifth Circuit earlier this month issued a highly unusual decision addressing whether state law could "reverse preempt" the New York Convention.}]
# [{'sentence': 'If a resource is more than 75% busy for sustained periods, take a closer look to see whether or not that level of utilization is acceptable in terms of response time or queue length.', 'predicate': {'token': 'see', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not that level of utilization is acceptable in terms of response time or queue length', 'type': 'polar'}]
# [{'sentence': We deny the right of such representation of the female members of the family, but granting this right, for argument's sake, it is very doubtful whether the one vote expresses the views and convictions of all the other members of the family.}]
# [{'sentence': 'If you have a treatment center in mind you should contact them to determine whether or not they accept your insurance.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not they accept your insurance', 'type': 'polar'}]
# [{'sentence': Whether or not it casts those who were directly responsible in a negative light is irrelevant and, frankly, quite insignificant to the larger meaning attributed to the stories.}]
# [{'sentence': Whether the factory dumps each day is random (so not all factories are active every day, in fact, if all factories were active every day, we couldn't tease apart their signals).}]
# [{'sentence': 'The court of protection decides whether an attorney who is acting under an existing of the lasting power of attorney should be removed or not.', 'predicate': {'token': 'decides', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether an attorney who is acting under an existing of the lasting power of attorney should be removed or not', 'type': 'polar'}]
# [{'sentence': Since both of these are part of the reasons why America is in trouble, the stability of a new America depends on whether or not they remain influential.}]
# [{'sentence': 'That, along with the location, helps determine whether the owners would be content living in the given area for the long term.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether the owners would be content living in the given area for the long term', 'type': 'polar'}]
# [{'sentence': We are still unclear as to whether or not Canada is a state.}]
# [{'sentence': 'The lead researcher has now begun further experiments to determine whether this drug can be used to formulate new treatments.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether this drug can be used to formulate new treatments', 'type': 'polar'}]
# [{'sentence': "I don't know whether I agree on the parents being unsupportive.", 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether I agree on the parents being unsupportive', 'type': 'polar'}]
# [{'sentence': "Silly, since everybody have little bits about them that are different from most others, but it can be those very things that decide whether or not you're successful with a person.", 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': "whether or not you're successful with a person", 'type': 'polar'}]
# [{'sentence': But, if the compounds that need to be separated remain colorless, it would be difficult to indicate whether you have obtained the desired compounds or not.}]
# [{'sentence': "If you need help with your online debt payment processing, or you're curious whether we can provide you with a more affordable alternative, you can always reach us here.", 'predicate': {'token': 'curious', 'pos': 'ADJ', 'preposition': None}, 'clause': 'whether we can provide you with a more affordable alternative, you can always reach us here', 'type': 'polar'}]
# [{'sentence': [39] As evidence of this, In Thomas de Quinceys Confessions of an English Opium-Eater (1821, p. 188), it is not Ottoman, nor Chinese, addicts about whom he writes, But English opium users: "I question whether any Turk, of all that ever entered the paradise of opium-eaters, can have had half the pleasure I had."}]
# [{'sentence': Most studies using D-aspartic acid supplements did not report whether side effects occurred; long-term studies have not yet been performed using D-aspartic acid.}]
# [{'sentence': 'Further study is needed to determine whether it should be cycled.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether it should be cycled', 'type': 'polar'}]
# [{'sentence': This aims to help people understand whether they are saving enough for retirement and what they can do to make sure they are prepared for the future in terms of their job, money and health.}]
# [{'sentence': And these requirements do not reflect the complex and often messy realities of innovation, let alone capture whether the innovation has negative consequences, such as putting CFCs in refrigerators.}]
# [{'sentence': 'A great deal of expertise has been developed around innovation surveys that ask firms whether they innovate, and in what forms.', 'predicate': {'token': 'ask', 'pos': 'VERB', 'preposition': None}, 'clause': 'firms whether they innovate, and in what forms', 'type': 'polar'}]
# [{'sentence': 'We must consider upon the evidence before us whether the Germans of the first century held land in private ownership.', 'predicate': {'token': 'consider', 'pos': 'VERB', 'preposition': None}, 'clause': 'upon the evidence before us whether the Germans of the first century held land in private ownership', 'type': 'polar'}]
# [{'sentence': 'Once the affidavit and proposed order have been received by the court, a judge will consider all of the information your provided and determine whether you qualify for poor person status.', 'predicate': {'token': 'consider', 'pos': 'VERB', 'preposition': None}, 'clause': 'all of the information your provided and determine whether you qualify for poor person status', 'type': 'polar'}, {'sentence': 'Once the affidavit and proposed order have been received by the court, a judge will consider all of the information your provided and determine whether you qualify for poor person status.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether you qualify for poor person status', 'type': 'polar'}]
# [{'sentence': Sometimes the outcome in a student's life is not dependent on whether he/she studied at an Ivy League school.}]
# [{'sentence': Whether the judge will agree with Rocco depends on what Rocco's reasons are for wanting to live with his father in London.}]
# [{'sentence': 'Marquette went test optional in June, allowing applicants to decide whether to include standardized test scores in their applications.', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether to include standardized test scores in their applications', 'type': 'polar'}]
# [{'sentence': 'Our group of researchers and students considered whether there is a linear link between physical activity levels and mental health and whether sedentary habits, such as sitting all day, influenced this relationship.', 'predicate': {'token': 'considered', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether there is a linear link between physical activity levels and mental health and whether sedentary habits, such as sitting all day, influenced this relationship', 'type': 'polar'}]
# [{'sentence': 'During a conference call earlier this week, I asked the UNDR\'s Communications Chief William Orme whether “global south was still a useful term."', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': "the UNDR's Communications Chief William Orme whether “global south was still a useful term.", 'type': 'polar'}]
# [{'sentence': 'The Good Samaritan did not ask whether the man lying on the road had health insurance.', 'predicate': {'token': 'ask', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether the man lying on the road had health insurance', 'type': 'polar'}]
# [{'sentence': 'But, unlike today, we did not immediately ask them whether we could withdraw food, water and antibiotics to get the death over with as soon as possible.', 'predicate': {'token': 'ask', 'pos': 'VERB', 'preposition': None}, 'clause': 'them whether we could withdraw food, water and antibiotics to get the death over with as soon as possible', 'type': 'polar'}]
# [{'sentence': But as yet, we still need to do more research before we can conclude with any certainty whether mixing by the marine biosphere is an important part of the ocean's circulation.}]
# [{'sentence': "In the current research, Mouradian's team asked whether EHT and caffeine could work together for even greater brain protection.", 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether EHT and caffeine could work together for even greater brain protection', 'type': 'polar'}]
# [{'sentence': "In essence, we just don't know whether the benefits of chest x-rays outweigh the harms (this is important and we'll come back to it later).", 'predicate': {'token': 'know', 'pos': 'VERB', 'preposition': None}, 'clause': "whether the benefits of chest x-rays outweigh the harms (this is important and we'll come back to it later)", 'type': 'polar'}]
# [{'sentence': 'The president will decide in the next few hours whether or not he got enough of what he wanted.', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': 'in'}, 'clause': 'the next few hours whether or not he got enough of what he wanted', 'type': 'polar'}]
# [{'sentence': 'The police searched this cabin in the caravan park and the owner gave them the address of the couple, but little more is known about this — and whether there is any information connecting Spedding to this cabin.', 'predicate': {'token': 'known', 'pos': 'VERB', 'preposition': 'about'}, 'clause': 'this — and whether there is any information connecting Spedding to this cabin', 'type': 'polar'}]
# [{'sentence': The police searched the dense bushland of Bonny Hills and Lake Cathie after other tip-offs, but again, it is unknown if there was anything found, and whether this was connected to Spedding.}]
# [{'sentence': 'This information regarding vehicles of interest was not made public knowledge until 12 months after the disappearance, and it is wondered whether an earlier public appeal could have helped the investigation significantly.', 'predicate': {'token': 'wondered', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether an earlier public appeal could have helped the investigation significantly', 'type': 'polar'}]
# [{'sentence': Although this is not the direction that investigators are moving forward with, it is crucial to establish whether this change of direction is justified.}]
# [{'sentence': 'Where #PeriodsOptional (women can decide whether or not to have periods and have access to the technology/medicine to do so)', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not to have periods and have access to the technology/medicine to do so', 'type': 'polar'}]
# [{'sentence': Where every child is planned (or at least not unwelcome) Where people are not judged by the clothes/shoes/makeup/hair they wear.}]
# [{'sentence': 'President Donald Trump is considering whether to pull out of the nuclear deal signed with Iran by his predecessor Barack Obama.', 'predicate': {'token': 'considering', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether to pull out of the nuclear deal signed with Iran by his predecessor Barack Obama', 'type': 'polar'}]
# [{'sentence': 'We can consider whether other specialists such as dermatologists may be needed in your treatment plan.', 'predicate': {'token': 'consider', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether other specialists such as dermatologists may be needed in your treatment plan', 'type': 'polar'}]
# [{'sentence': But nobody continued to question (as they once had) whether or not the internet was really necessary.}]
# [{'sentence': Organic acids testing is a way to measure whether your body is getting and using the nutrients needed for key metabolic processes.}]
# [{'sentence': We didn't want to worry about whether or not we'd have a paycheck every week.}]
# [{'sentence': Such clustering, though, is not against any NCAA regulations, and it's not even clear whether, or how, the NCAA monitors clustering.}]
# [{'sentence': 'Given the transparent, barely perceptible nature of contact lenses, the first thing you should do is determine whether or not the lens is really still in your eye.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not the lens is really still in your eye', 'type': 'polar'}]
# [{'sentence': 'They will observe the way employees handle their mistakes to determine whether they will excel in their work environment.', 'predicate': {'token': 'determine', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether they will excel in their work environment', 'type': 'polar'}]
# [{'sentence': And whether he is able or not to shoot good pictures seems to be totally irrelevant.}]
# [{'sentence': I still get confused as to whether I'm being selfish and in typing this comment I can actually feel myself looking for affirmation from you and other posters.}]
# [{'sentence': I still doubt at times whether I am making mountains out of mole hills.}]
# [{'sentence': 'Following a decision by the review panel, [plaintiff] will then decide whether or not to file a malpractice action.', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not to file a malpractice action', 'type': 'polar'}]
# [{'sentence': Whether a plaintiff who is currently proceeding before medical review panel pursuant to the [statute] may later allege and prove a medical malpractice claim in a state or federal court case is not relevant to the determination of diversity jurisdiction at the time of removal.}]
# [{'sentence': LOS ANGELES (AP / FOX 11) -}]
# [{'sentence': The bankruptcy of the Hanjin shipping line has thrown ports and retailers around the world into confusion, with giant container ships marooned and merchants worrying whether tons of goods will reach their shelves.}]
# [{'sentence': "However, unless you're deficient in calcium, which can lead to hair loss, there isn't enough clinical evidence to say whether or not supplementation will provide any hair benefits.", 'predicate': {'token': 'say', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether or not supplementation will provide any hair benefits', 'type': 'polar'}]
# [{'sentence': 'No Zones (significant blind spots) can make it difficult for a truck driver to tell whether a lane is clear before merging.', 'predicate': {'token': 'tell', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether a lane is clear before merging', 'type': 'polar'}]
# [{'sentence': A Dallas spinal cord injury lawyer can help truck accident victims recognize whether or not someone else is liable for damages after a serious spinal cord injury.}]
# [{'sentence': If a truck driver caused a serious accident or wrongful death, an accident attorney can most likely discover whether he or she cheated on the logbooks.}]
# [{'sentence': So if a trader has an interest in a particular offer, he must find out whether his broker offers that or not.}]
# [{'sentence': The parents of a teenager who was forced to leave a specialist school that supports children with severe autism in Bristol are investigating whether they can sue the education watchdog.}]
# [{'sentence': 'The problem was this: I had a hard time caring about whether or not Jon Snow was alive, when I knew that, for sure, Prince was dead.', 'predicate': {'token': 'knew', 'pos': 'VERB', 'preposition': None}, 'clause': 'that, for sure, Prince was dead', 'type': 'declarative'}]
# ...
# [{'sentence': 'So I called Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it.', 'predicate': {'token': 'asked', 'pos': 'VERB', 'preposition': None}, 'clause': 'him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it', 'type': 'alternative'}]
# [{'sentence': We just have to guess whether the card on the card on the player or the banker who will be the winner, or the game ends in a tie.}]
# [{'sentence': 'For centuries Jewish villages had to decide whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry.', 'predicate': {'token': 'decide', 'pos': 'VERB', 'preposition': None}, 'clause': 'whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry', 'type': 'alternative'}, {'sentence': 'For centuries Jewish villages had to decide whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry.', 'predicate': {'token': 'hope', 'pos': 'VERB', 'preposition': None}, 'clause': 'to survive hard times, or whether to flee across rivers and borders with what they could carry', 'type': 'alternative'}]
# [{'sentence': You cant easily configure whether you want the video to be oriented horizontally (landscape) or vertically (portrait).}]
# [{'sentence': This includes the rights to property, the ability to raise children, and whether you will pay or receive alimony.}]
# [{'sentence': I've gone back and forth on whether Desire or BOTT is my favorite Dylan record (with Blonde on Blonde working it's way in there from time to time).}]
# [{'sentence': What difference does it make whether Jesus or the Holy Spirit lives in my heart?.}]
# [{'sentence': Shower Doors is a relatively small company that can offer you more personalized service, which is something not offered by many companies today.}]
# [{'sentence': Hardware is very well made, offering a diverse selection of style and color}]
# [{'sentence': Hardware is very durable and offers you many years of trouble free operation.}]
# [{'sentence': He has only just become a free agent, but if this report is true then he will have many former teammates to play with, including Lucas 'LUCAS1' Teles, Henrique 'HEN1' Teles, and Lucas 'steel' Lopes.}]
# [{'sentence': Now that you know your priorities and price range, use the criteria to narrow your home search}]
# [{'sentence': Start with my Featured Listings to see examples of beautiful North Shore homes}]
# [{'sentence': Contact me to arrange a personal showing of any home in the North Shore area!}]
# [{'sentence': We took to the only wildflower field that I could find this year, which was in Huntsville}]
# [{'sentence': The park itself is just so beautiful and compliments my Outdoor Family Photography Woodlands session collection so nicely}]
# [{'sentence': I love the rich colors it has to offer and the beautiful family that I was able to photograph}]
# [{'sentence': No complaining here!!!}]
# [{'sentence': Tweet Me if You Love Me!}]
# [{'sentence': If you’d like to learn more about my sessions, click here}]
# [{'sentence': 'And to get in touch, ask questions, or just say hi.', 'predicate': {'token': 'ask', 'pos': 'VERB', 'preposition': None}, 'clause': 'questions, or just say hi', 'type': 'declarative'}]
# [{'sentence': drop me a line}]
# [{'sentence': I’d love to hear from you.}]
# [{'sentence': If you are self conscious about your arms, wear sleeves.}]
# [{'sentence': 'If you don’t like dresses, don’t wear one!', 'predicate': {'token': 'like', 'pos': 'VERB', 'preposition': None}, 'clause': 'dresses, don’t wear one', 'type': 'declarative'}]
# [{'sentence': If your husband doesn’t love suspenders and has never worn them a day in his life, please leave those at the store}]
# [{'sentence': So if you aren’t one to dress in a cowboy hat and boots then why would you for a photo shoot}]
# [{'sentence': Just don’t do it}]
# [{'sentence': If you love white and jeans, find different styles of white shirts and different tones of blue jeans (dark, weathered, light, etc)}]
# [{'sentence': This is all great information, but where do you get all these dreamy clothes?}]
# [{'sentence': And if you do not want to purchase clothing, I do have a few clothing options if you’d like to come to the studio to take a look.}]
# [{'sentence': 'My goal is to document your life the way your kids sees it, and the way you want to be remembered.', 'predicate': {'token': 'sees', 'pos': 'VERB', 'preposition': None}, 'clause': 'it, and the way you want to be remembered', 'type': 'declarative'}]
# [{'sentence': when you click with your clients, magic kind of happens}]
# [{'sentence': I clicked with this beautiful family and found a new friend in this little 4 year old}]
# [{'sentence': My family and I have had an interesting couple of weeks, to say the least}]
# [{'sentence': My husband graduated (HOORAY!) from Sam Houston after a long time of blood, sweat, and tears}]
# [{'sentence': We took to a location I had my eyes on for about a year}]
# [{'sentence': I was waiting for the perfect type of session to take to this specific place}]
# [{'sentence': Aubrie was a sleep fighter of champs but we managed to get a few minutes of her sleeping on her belly towards the end of her The Woodlands Newborn Studio session}]
# [{'sentence': Below are summaries of the crashes of the seriously injured or fatally inured person who were not listed as in error of traveling in the wrong lane or crossing the center line}]
# [{'sentence': Of course all incident reports are not final and do not represent proof of fault of any driver}]
# [{'sentence': In each of these collisions as reported by the MSHP a vehicle crossed the center line and struck another vehicle head-on or in several instances, a driver was driving the wrong way on a highway and then struck another vehicle head-on}]
# [{'sentence': Louis, MO woman and an 18 year-old Hannibal, MO woman were both seriously injured when a Toyota Matrix driven by an 18 year-old Country Club Hills, IL man crossed the center line and struck their Mazda.}]
# [{'sentence': February 17, 2019, Adair County, Hwy 6: A 34 year-old Brashear, MO man was seriously injured along with his 10 year-old son when a 28 year-old Canton, MO man crossed the center line on icy highway and struck their Jeep head-on}]
# [{'sentence': The 28 year-old driver of the Ford truck was also seriously injured.}]
# [{'sentence': March 25, 2019; Stone County, MO 143: An 82 year-old Crane, MO woman was killed when her Chevy HHR was struck head-on by a Ford Ranger driven by a 68 year-old Marionville, MO man}]
# [{'sentence': March 27, 2019, Christian County, US 6: A 67 year-old Reeds Spring, MO man was killed when a Chevy Impala crossed the median and struck his Harley Davidson motorcycle, two other motorcyclist were seriously injured as one was also hit head-on and another motorcyclist was struck by debris}]
# [{'sentence': The two seriously injured motorcyclists include a 70 year-old man and a 67 year-old man from Springfield, MO}]
# [{'sentence': The driver of the Impala was also seriously injured.}]
# [{'sentence': As evident, head-on car collisions are serious crashes}]
# [{'sentence': There are a number of reasons head-on collisions occur such as inattentiveness, improper passing, distracted driving and driving under the influence}]
# [{'sentence': The commonalities in each of these crashes are serious injuries and death}]
# [{'sentence': No one should have to face the insurance negotiations or potential litigation on their own.}]
# [{'sentence': Transform your dingy old chairs to beautiful seating arrangements for all of your guests}]
# [{'sentence': With our more than 80 different color options for sash matching, you can personalize your decorations to meet your expectations.}]
# [{'sentence': Health Assist ZONE offers seven bundled plans with varying levels of health, dental, drug and travel coverage at competitive prices - plus a few added perks.}]
# [{'sentence': Over the years, we gave our absolute best to deliver quality locksmith services to the people of Zip Code 80211 at an affordable price}]
# [{'sentence': Today, be it a simple lock repair or duplication of high-security keys, people rely on only one name: Town Center Locksmith Shop.}]
# [{'sentence': Do you have a solution to completely disable this feature?}]
# [{'sentence': I could find this other answer which can help you to disable the blogposts.}]
# [{'sentence': How can I disable adding Blog Posts?}]
# [{'sentence': So, if you desire to receive these amazing images about (Awesome Baby Shower Clipart), click on save icon to store the graphics to your laptop}]
# [{'sentence': They are ready for download, if you appreciate and want to obtain it, click save badge in the page, and it’ll be directly saved in your notebook computer}]
# [{'sentence': Last time we gave the crown to dynamic duo Rose and Rosie}]
# [{'sentence': This week, we’re giving the title to the hilarious Tiny Tim’s Adventures!}]
# [{'sentence': Who is Tiny Tim’s Adventures?}]
# [{'sentence': Why should you watch Tiny Tim’s videos?}]
# [{'sentence': If you need something to brighten your day, then Tiny Tim’s channel is for you}]
# [{'sentence': The concept is simple; Tiny Tim’s videos are a series of prank calls in which he puts on a child’s voice and pretends to be a kid navigating his way through adult life}]
# [{'sentence': From trying to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult.}]
# [{'sentence': You’re not really going to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face}]
# [{'sentence': It’s impossible to watch any of Tim’s videos without belly laughing}]
# [{'sentence': When life brings you down, Tim’s cheeky nature will lighten the mood for sure.}]
# [{'sentence': The phone call gets passed around a number of confused staff members, which adds to the hilarity of the video}]
# [{'sentence': He phones a jewellers to get advice on the best engagement ring to buy.}]
# [{'sentence': When in Spain, he goes on the hunt for his real padre with hilarious consequences.}]
# [{'sentence': I develop isomorphic apps with Ractive and have webpack building and packaging for different environments except NodeJS}]
# [{'sentence': I don't need any building process on NodeJS right now, but I should do this in your case.}]
# [{'sentence': In my case I use the component files via RVC (RequireJS)}]
# [{'sentence': For me there's no build step - ie, components are loaded straight in the browser.}]
# [{'sentence': CommonJS2 is the only modular system which works stable right now and could be compiled for other environments via Webpack.}]
# [{'sentence': Suggesting tool-specific procedures and folder structures would be against its intended design.}]
# [{'sentence': There are entities who lock down their network to the point that there's no npm and therefore no build tools.}]
# [{'sentence': but what's the point of two different versions?}]
# [{'sentence': Actually, it doesn't matter because including Webpack to you module you give to the user the ability to build any kind of module they need.}]
# [{'sentence': It's almost zero-friction, since it's all JS}]
# [{'sentence': Buble takes care of the ES, Rollup takes care of the modules, and I usually output an IIFE and stick it to the HTML.}]
# [{'sentence': I don't use this approach because it little bit weird to me - all stuff in one big file, like PHP did before.}]
# [{'sentence': But you still need to use Babel and Rollup even if you need to run this code in NodeJS}]
# [{'sentence': I'm not because my modules already ready-to-use in NodeJS and ready-to-compile with Webpack.}]
# [{'sentence': This is something I still haven't fully considered yet}]
# [{'sentence': Though dynamic imports aren't actually a thing yet, so..}]
# [{'sentence': The intensive course is the course that has the most varied type of students, with participants of all age groups and backgrounds.}]
# [{'sentence': This course is for students that are not able to stay for long periods in Spain, and need to improve their Spanish in a short span of time}]
# [{'sentence': 'If you would like to take an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs.', 'predicate': {'token': 'like', 'pos': 'VERB', 'preposition': None}, 'clause': 'to take an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs', 'type': 'declarative'}]
# [{'sentence': The intensive monthly course is a 4 hour per day program that has 6 different levels available.}]
# [{'sentence': Finding Inspiration is always something I have to do to stay involved in the creative process}]
# [{'sentence': If I don’t have any inspiration I won’t create and I need to create as an outlet}]
# [{'sentence': Clearing my mind and my physical space is important}]
# [{'sentence': Usually before I can get creative I organize my space}]
# [{'sentence': and I also need to be able to relax}]
# [{'sentence': Being in the right state of mind is extremely important for me to be inspired}]
# [{'sentence': I sometimes need to feed my creativity and nurture my own ability}]
# [{'sentence': This is sometimes difficult to find an experience that truly fuels and nurtures}]
# [{'sentence': 'Listening to a song, or seeing a photograph or reading an article can be inspirational at times', 'predicate': {'token': 'seeing', 'pos': 'VERB', 'preposition': None}, 'clause': 'a photograph or reading an article can be inspirational at', 'type': 'declarative'}]
# [{'sentence': I’d like to learn more ways so inspiration can be controlled.}]
# [{'sentence': The fact is, not everyone intends to be your Facebook friend}]
# [{'sentence': Everyone makes use of Facebook in different ways, some approve good friend requests from everyone, others wish to keep job and residence life different, while some people just disregard requests completely.}]
# [{'sentence': Exhibits in Landscapes of Life include an immersive audio-visual theatre showing personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field.}]
# [{'sentence': Included in the entry price for the exhibition is access to the Arboretum’s temporary exhibition gallery and an audio guide which can be used to explore and learn about 93 of the memorials across the Arboretum site.}]
# [{'sentence': HotelHome Paris 16 is 1,000 feet from Jasmin Metro Station, which offers direct access to the Eiffel Tower and the Champs-Élysées}]
# [{'sentence': 'When would you like to stay at HotelHome Paris 16?', 'predicate': {'token': 'like', 'pos': 'VERB', 'preposition': None}, 'clause': 'to stay at HotelHome Paris 16', 'type': 'declarative'}]
# [{'sentence': We chose to buy thisapart-hotel in 2002 because we like to welcome and receive our guests not only as customers but as friends}]
# [{'sentence': We love to make their stay pleasant and comfortable in a very friendly atmosphere}]
# [{'sentence': Choosing HotelHome Paris 16 is choosing a helpful staff, unique apartments, and a team at your service}]
# [{'sentence': Your stay will earn in quality.}]
# [{'sentence': If you plan to arrive later than 18:00 or on a weekend, please contact the hotel in advance to obtain the main door access code.}]
# [{'sentence': The lift is to small, so it takes time to bring the luggage to the 5th fl.}]
# [{'sentence': Beds need to be renewed because they are noisy and uncomfortable.}]

# %%
#predicted sets - natural
out_dec = pd.read_csv('/content/drive/My Drive/samples/baseline_declarative_golden.csv')
out_pol = pd.read_csv('/content/drive/My Drive/samples/baseline_polar_golden.csv')
out_con = pd.read_csv('/content/drive/My Drive/samples/baseline_constituent_golden.csv')
out_alt = pd.read_csv('/content/drive/My Drive/samples/baseline_alternative_golden.csv')
out_adv = pd.read_csv('/content/drive/My Drive/samples/baseline_adversarial_golden.csv')

# %%
#stats for evaluation

#contains clause, overall - precision and recall
def contains_clause_f1(pred_list, true_list):
  tp = 0
  fp = 0
  tn = 0
  fn = 0

  for s in range(len(pred_list)):
    if pred_list[s] == 0 and true_list[s] == 0:
      tn += 1
    if pred_list[s] == 1 and true_list[s] == 0:
      fp += 1
    if pred_list[s] == 0 and true_list[s] == 1:
      fn += 1
    if pred_list[s] == 1 and true_list[s] == 1:
      tp += 1

  precision = tp/(tp+fp)
  recall = tp/(tp+fn)
  f1 = (2*precision*recall)/(precision + recall)

  print("Overall Clause Prediction Precision: ", precision)
  print("Overall Clause Prediction Recall: ", recall)
  print("Overall Clause Prediction F1: ", f1)



#contains clause, per type - accuracy
def contains_clause_acc(typ, pred_list, true_list):
  correct = 0
  total = len(pred_list)

  for s in range(len(pred_list)):
    if pred_list[s] == 0 and true_list[s] == 0:
      correct += 1
    if pred_list[s] == 1 and true_list[s] == 1:
      correct += 1

  accuracy = correct/total

  print(typ, "Clause Prediction Accuracy: ", accuracy)



#type - accuracy
def type_acc(typ, pred_list, true_list):
  correct = 0
  total = 0

  for s in range(len(pred_list)):
    if type(pred_list[s]) == str:
      total += 1
      if true_list[s] == pred_list[s]:
        correct += 1

  accuracy = correct/total

  print(typ, "Type Prediction Accuracy: ", accuracy)



#predicate - accuracy
def predicate_acc(typ, pred_list, true_list):
  correct = 0
  total = 0

  for s in range(len(pred_list)):
    if type(pred_list[s]) == str:
      total += 1
      if true_list[s] == pred_list[s]:
        correct += 1

  accuracy = correct/total

  print(typ, "Predicate Prediction Accuracy: ", accuracy)

# %%
#get sample stats
full_pred = list(out_samp['has_clause'])
full_true = []

for i in samples:
  full_true = full_true + list(i['has_clause'])

contains_clause_f1(full_pred, full_true)

print()

dec_pred = list(out_samp['has_clause'])[:10]
pol_pred = list(out_samp['has_clause'])[10:20]
con_pred = list(out_samp['has_clause'])[20:30]
alt_pred = list(out_samp['has_clause'])[30:40]
adv_pred = list(out_samp['has_clause'])[40:50]

contains_clause_acc("Declarative", dec_pred, list(dec_samp['has_clause']))
contains_clause_acc("Polar", pol_pred, list(pol_samp['has_clause']))
contains_clause_acc("Constituent", con_pred, list(con_samp['has_clause']))
contains_clause_acc("Alternative", alt_pred, list(alt_samp['has_clause']))
contains_clause_acc("Adversarial", adv_pred, list(adv_samp['has_clause']))

print()

dec_pred = list(out_samp['type'])[:10]
pol_pred = list(out_samp['type'])[10:20]
con_pred = list(out_samp['type'])[20:30]
alt_pred = list(out_samp['type'])[30:40]

type_acc("Declarative", dec_pred, list(dec_samp['type']))
type_acc("Polar", pol_pred, list(pol_samp['type']))
type_acc("Constituent", con_pred, list(con_samp['type']))
type_acc("Alternative", alt_pred, list(alt_samp['type']))

print()

dec_pred = list(out_samp['predicate'])[:10]
pol_pred = list(out_samp['predicate'])[10:20]
con_pred = list(out_samp['predicate'])[20:30]
alt_pred = list(out_samp['predicate'])[30:40]

predicate_acc("Declarative", dec_pred, list(dec_samp['predicate']))
predicate_acc("Polar", pol_pred, list(pol_samp['predicate']))
predicate_acc("Constituent", con_pred, list(con_samp['predicate']))
predicate_acc("Alternative", alt_pred, list(alt_samp['predicate']))
# Out:
# Overall Clause Prediction Precision:  0.9047619047619048
# Overall Clause Prediction Recall:  0.95
# Overall Clause Prediction F1:  0.9268292682926829
#
# Declarative Clause Prediction Accuracy:  0.9
# Polar Clause Prediction Accuracy:  1.0
# Constituent Clause Prediction Accuracy:  1.0
# Alternative Clause Prediction Accuracy:  0.9
# Adversarial Clause Prediction Accuracy:  0.6
#
# Declarative Type Prediction Accuracy:  1.0
# Polar Type Prediction Accuracy:  1.0
# Constituent Type Prediction Accuracy:  1.0
# Alternative Type Prediction Accuracy:  1.0
#
# Declarative Predicate Prediction Accuracy:  1.0
# Polar Predicate Prediction Accuracy:  1.0
# Constituent Predicate Prediction Accuracy:  1.0
# Alternative Predicate Prediction Accuracy:  1.0

# %%
#get golden stats
full_pred = list(out_dec['has_clause']) + list(out_pol['has_clause']) + list(out_con['has_clause']) + list(out_alt['has_clause']) + list(out_adv['has_clause'])
full_true = []

for i in golds:
  full_true = full_true + list(i['has_clause'])

contains_clause_f1(full_pred, full_true)

print()

dec_pred = list(out_dec['has_clause'])
pol_pred = list(out_pol['has_clause'])
con_pred = list(out_con['has_clause'])
alt_pred = list(out_alt['has_clause'])
adv_pred = list(out_adv['has_clause'])

contains_clause_acc("Declarative", dec_pred, list(decl_gold['has_clause']))
contains_clause_acc("Polar", pol_pred, list(pol_gold['has_clause']))
contains_clause_acc("Constituent", con_pred, list(const_gold['has_clause']))
contains_clause_acc("Alternative", alt_pred, list(alt_gold['has_clause']))
contains_clause_acc("Adversarial", adv_pred, list(adv_gold['has_clause']))

print()

dec_pred = list(out_dec['type'])
pol_pred = list(out_pol['type'])
con_pred = list(out_con['type'])
alt_pred = list(out_alt['type'])

type_acc("Declarative", dec_pred, list(decl_gold['type']))
type_acc("Polar", pol_pred, list(pol_gold['type']))
type_acc("Constituent", con_pred, list(const_gold['type']))
type_acc("Alternative", alt_pred, list(alt_gold['type']))

print()

dec_pred = list(out_dec['predicate'])
pol_pred = list(out_pol['predicate'])
con_pred = list(out_con['predicate'])
alt_pred = list(out_alt['predicate'])

predicate_acc("Declarative", dec_pred, list(decl_gold['predicate']))
predicate_acc("Polar", pol_pred, list(pol_gold['predicate']))
predicate_acc("Constituent", con_pred, list(const_gold['predicate']))
predicate_acc("Alternative", alt_pred, list(alt_gold['predicate']))
# Out:
# Overall Clause Prediction Precision:  0.9746835443037974
# Overall Clause Prediction Recall:  0.5043668122270742
# Overall Clause Prediction F1:  0.6647482014388489
#
# Declarative Clause Prediction Accuracy:  0.4690265486725664
# Polar Clause Prediction Accuracy:  0.5
# Constituent Clause Prediction Accuracy:  0.5983606557377049
# Alternative Clause Prediction Accuracy:  0.42696629213483145
# Adversarial Clause Prediction Accuracy:  0.9459459459459459
#
# Declarative Type Prediction Accuracy:  0.9433962264150944
# Polar Type Prediction Accuracy:  0.8507462686567164
# Constituent Type Prediction Accuracy:  0.958904109589041
# Alternative Type Prediction Accuracy:  0.9736842105263158
#
# Declarative Predicate Prediction Accuracy:  0.8867924528301887
# Polar Predicate Prediction Accuracy:  0.8208955223880597
# Constituent Predicate Prediction Accuracy:  0.7534246575342466
# Alternative Predicate Prediction Accuracy:  0.8157894736842105
