# %%
import benepar, spacy
import os
import re
from typing import List, Set, Dict, Tuple
from spacy import displacy
from spacy.matcher import Matcher
from spacy.tokenizer import Tokenizer
import warnings
import csv
import pandas as pd
import math

warnings.filterwarnings('ignore')

# %%
benepar.download('benepar_en3')
nlp = spacy.load('en_core_web_md')

if spacy.__version__.startswith('2'):
    nlp.add_pipe(benepar.BeneparComponent("benepar_en3"))
else:
    nlp.add_pipe("benepar", config={"model": "benepar_en3"})
# Out:
# [nltk_data] Downloading package benepar_en3 to
# [nltk_data]     C:\Users\sivan\AppData\Roaming\nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
#process golden sets for eval

gold_sets = pd.read_json('../Annotation/golden_sets_flattened.json').transpose()

gold_annotations = []
for index, row in gold_sets.iterrows():
  entry = {'sentence': row['sentence'], 'predicate': row['predicate'], 'clause': row['clause'], 'type': row['type']}
  gold_annotations.append(entry)
  print(entry)

gold_sentences = list(dict.fromkeys([g['sentence'] for g in gold_annotations]))
print(gold_sentences)


advers_sets = pd.read_json('../Annotation/adversarials_golden_set.json').transpose()
advers_sentences = []
for index, row in advers_sets.iterrows():
  advers_sentences.append(row['sentence'])

print(advers_sentences)
# Out:
# {'sentence': "Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.", 'predicate': [{'str': 'reports', 'lemma': 'report', 'POS': 'VERB'}], 'clause': "that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel", 'type': 'declarative'}
# {'sentence': 'I have always loved fashion and believe that it plays an integral role in self expression', 'predicate': [{'str': 'believe', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': 'that it plays an integral role in self expression', 'type': 'declarative'}
# {'sentence': 'Being a Conroe and Woodlands Family Photographer, I find that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions)', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions)', 'type': 'declarative'}
# {'sentence': 'I can honestly say that that is precisely what happened on this day', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that that is precisely what happened on this day', 'type': 'declarative'}
# {'sentence': 'I have decided that I want her to be my pen pal and take it back old school', 'predicate': [{'str': 'decided', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'that I want her to be my pen pal and take it back old school', 'type': 'declarative'}
# {'sentence': 'They were up for something different and an adventure, so I felt it was a great opportunity to shoot in!', 'predicate': [{'str': 'felt', 'lemma': 'feel', 'POS': 'VERB'}], 'clause': 'it was a great opportunity to shoot in', 'type': 'declarative'}
# {'sentence': 'I am also praying that everyone who flooded is doing ok and things are getting back to normal!', 'predicate': [{'str': 'praying', 'lemma': 'pray', 'POS': 'VERB'}], 'clause': 'that everyone who flooded is doing ok', 'type': 'declarative'}
# {'sentence': 'I am also praying that everyone who flooded is doing ok and things are getting back to normal!', 'predicate': [{'str': 'praying', 'lemma': 'pray', 'POS': 'VERB'}], 'clause': 'things are getting back to normal', 'type': 'declarative'}
# {'sentence': 'I also should mention that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session.', 'predicate': [{'str': 'mention', 'lemma': 'mention', 'POS': 'VERB'}], 'clause': 'that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session', 'type': 'declarative'}
# {'sentence': 'This is not to say that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'type': 'declarative'}
# {'sentence': 'When we laid our foundation stone in Denver, CO 80211 almost 10 years ago, we realized that the people of the city have been desperately missing the services of a professional locksmith company', 'predicate': [{'str': 'realized', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'that the people of the city have been desperately missing the services of a professional locksmith company', 'type': 'declarative'}
# {'sentence': 'For anyone following Tiny Tim’s adventures, we know that he lives with his mum and has never met his real dad', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that he lives with his mum', 'type': 'declarative'}
# {'sentence': 'For anyone following Tiny Tim’s adventures, we know that he lives with his mum and has never met his real dad', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'has never met his real dad', 'type': 'declarative'}
# {'sentence': "@avoto hm, I don't think that it's a good idea", 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': "that it's a good idea", 'type': 'declarative'}
# {'sentence': '@PaulMaly_twitter I was thinking that there can be more than one version where one is is the Ractive component file as per the official spec', 'predicate': [{'str': 'thinking', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'that there can be more than one version where one is is the Ractive component file as per the official spec', 'type': 'declarative'}
# {'sentence': 'I think the components should be written so that they could work without any compilation at least in one environment', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'the components should be written so that they could work without any compilation at least in one environment', 'type': 'declarative'}
# {'sentence': 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'type': 'declarative'}
# {'sentence': 'Here I argue that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed', 'predicate': [{'str': 'argue', 'lemma': 'argue', 'POS': 'VERB'}], 'clause': 'that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed', 'type': 'declarative'}
# {'sentence': 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'predicate': [{'str': 'believe', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': 'that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'type': 'declarative'}
# {'sentence': 'Yet, if we deny that Jones’ life has any real meaning because his pain outweighs his enjoyment of life then his worth is reduced to the sum total of the pain or the pleasure he is experiencing', 'predicate': [{'str': 'deny', 'lemma': 'deny', 'POS': 'VERB'}], 'clause': 'that Jones’ life has any real meaning because his pain outweighs his enjoyment of life', 'type': 'declarative'}
# {'sentence': 'Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)', 'predicate': [{'str': 'holds', 'lemma': 'hold', 'POS': 'VERB'}], 'clause': 'that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are”', 'type': 'declarative'}
# {'sentence': 'My parents have worked all of their lives and they always told me whether it is just a part-time job, a volunteer job, or your career, if you agreed to work for someone, do just that.', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'whether it is just a part-time job, a volunteer job, or your career, if you agreed to work for someone, do just that', 'type': 'declarative'}
# {'sentence': 'It is to admit that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them.', 'predicate': [{'str': 'admit', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': 'that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them', 'type': 'declarative'}
# {'sentence': 'However, defining mercy solely as relationship might indicate that euthanasia is not incompatible with mercy', 'predicate': [{'str': 'indicate', 'lemma': 'indicate', 'POS': 'VERB'}], 'clause': 'that euthanasia is not incompatible with mercy', 'type': 'declarative'}
# {'sentence': 'However, to accept this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'predicate': [{'str': 'admit', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': 'that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'type': 'declarative'}
# {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': [{'str': 'write', 'lemma': 'write', 'POS': 'VERB'}], 'clause': '“Often, we learn that something is precious only when we see it in the light of someone’s love”', 'type': 'declarative'}
# {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': [{'str': 'learn', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'that something is precious', 'type': 'declarative'}
# {'sentence': 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'predicate': [{'str': 'seeing', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'that Jones is loved', 'type': 'declarative'}
# {'sentence': 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'predicate': [{'str': 'saying', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that new car sales took a nosedive in September', 'type': 'declarative'}
# {'sentence': 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'predicate': [{'str': 'signaling', 'lemma': 'signal', 'POS': 'VERB'}], 'clause': 'economic distress could be just around the corner', 'type': 'declarative'}
# {'sentence': 'News BREAKING: HHA owner Jon Kelly has revealed he was sacked on Monday as administrators Ferrier Hodgson announced the business was in voluntary administration.', 'predicate': [{'str': 'revealed', 'lemma': 'reveal', 'POS': 'VERB'}], 'clause': 'he was sacked on Monday', 'type': 'declarative'}
# {'sentence': 'News BREAKING: HHA owner Jon Kelly has revealed he was sacked on Monday as administrators Ferrier Hodgson announced the business was in voluntary administration.', 'predicate': [{'str': 'announced', 'lemma': 'announce', 'POS': 'VERB'}], 'clause': 'the business was in voluntary administration', 'type': 'declarative'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,”", 'type': 'declarative'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': "that I'm contributing in my own small way", 'type': 'declarative'}
# {'sentence': 'Did I forget to mention the home has 3 zone heat and Air conditioning on 1.8 acres of property on a no thruway street', 'predicate': [{'str': 'mention', 'lemma': 'mention', 'POS': 'VERB'}], 'clause': 'the home has 3 zone heat and Air conditioning on 1.8 acres of property on a no thruway street', 'type': 'declarative'}
# {'sentence': 'Ready-made Greens can be useful for mixing other colours too, we’re not suggesting you should chuck them out!', 'predicate': [{'str': 'suggesting', 'lemma': 'suggest', 'POS': 'VERB'}], 'clause': 'you should chuck them out', 'type': 'declarative'}
# {'sentence': 'You will see that small differences in the amount of black can make a big difference to the colour you make.', 'predicate': [{'str': 'see', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'that small differences in the amount of black can make a big difference to the colour you make', 'type': 'declarative'}
# {'sentence': 'One study found that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'predicate': [{'str': 'found', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'type': 'declarative'}
# {'sentence': 'One study found that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'predicate': [{'str': 'influence', 'lemma': 'influence', 'POS': 'VERB'}], 'clause': 'whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'type': 'polar'}
# {'sentence': 'I have so many things I want to write about I fear I’m bursting at the seams', 'predicate': [{'str': 'fear', 'lemma': 'fear', 'POS': 'VERB'}], 'clause': 'I’m bursting at the seams', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I was so stunned that it was meant for him', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'was', 'lemma': 'be', 'POS': 'AUX'}, {'str': 'stunned', 'lemma': 'stunned', 'POS': 'ADJ'}], 'clause': 'that it was meant for him', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': '“Did YOU HEAR THAT??”', 'type': 'declarative'}
# {'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': [{'str': 'understands', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': 'that he can do so much more then he thought he could', 'type': 'declarative'}
# {'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': [{'str': 'thought', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'he could', 'type': 'declarative'}
# {'sentence': 'He’s also told me he wants to try out for football next year', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'he wants to try out for football next year', 'type': 'declarative'}
# {'sentence': 'I don’t think I’m ready for the pain that’s going to go along with the teenage years', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I’m ready for the pain that’s going to go along with the teenage years', 'type': 'declarative'}
# {'sentence': "To any studio execs who may be reading this: I can't guarantee that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers.", 'predicate': [{'str': 'guarantee', 'lemma': 'guarantee', 'POS': 'VERB'}], 'clause': 'that following my advice will help your format win the war', 'type': 'declarative'}
# {'sentence': 'I realize this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'predicate': [{'str': 'realize', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'this may sound like a contradiction to my last point about getting straight to the movie', 'type': 'declarative'}
# {'sentence': "Just to reiterate that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'predicate': [{'str': 'reiterate', 'lemma': 'reiterate', 'POS': 'VERB'}], 'clause': "that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'type': 'declarative'}
# {'sentence': 'And that Jamie Schler article…I wish I were as fiery', 'predicate': [{'str': 'wish', 'lemma': 'wish', 'POS': 'VERB'}], 'clause': 'I were as fiery', 'type': 'declarative'}
# {'sentence': 'I think not letting one’s computer get in the way of real life is sound advice', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'not letting one’s computer get in the way of real life is sound advice', 'type': 'declarative'}
# {'sentence': 'Later in the article, Portnoy says that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things.', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things', 'type': 'declarative'}
# {'sentence': 'No matter how ridiculous the jokes, or over the top the take, it was understood by most that we are just here to make people laugh.', 'predicate': [{'str': 'understood', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': 'that we are just here to make people laugh', 'type': 'declarative'}
# {'sentence': 'On that count, he knows all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on.', 'predicate': [{'str': 'knows', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on', 'type': 'declarative'}
# {'sentence': 'and I guess they smelt well.', 'predicate': [{'str': 'guess', 'lemma': 'guess', 'POS': 'VERB'}], 'clause': 'they smelt well', 'type': 'declarative'}
# {'sentence': 'Michelle Obama says her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'type': 'declarative'}
# {'sentence': 'The First Lady told People Magazine the Obamas are searching animal rescues for that particular breed.', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'the Obamas are searching animal rescues for that particular breed', 'type': 'declarative'}
# {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}
# {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': [{'str': 'hopes', 'lemma': 'hope', 'POS': 'VERB'}], 'clause': 'the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}
# {'sentence': 'Obama says she learned from Sen', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'she learned from Sen', 'type': 'declarative'}
# {'sentence': "I know that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that Apple does provide a converter that turns the charging port into a headphone jack', 'type': 'declarative'}
# {'sentence': "I know that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'predicate': [{'str': 'means', 'lemma': 'mean', 'POS': 'VERB'}], 'clause': 'you have to do a lot of plugging and unplugging every time you want to listen to music', 'type': 'declarative'}
# {'sentence': 'Is it accurate to say that you are a specialist in a particular field?', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that you are a specialist in a particular field', 'type': 'declarative'}
# {'sentence': 'From movement, form, cooking, to DIY, and expulsion administrations, on the off chance that you realize how to accomplish something especially well, why not tell the world through a blog or video blog?', 'predicate': [{'str': 'realize', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'how to accomplish something especially well', 'type': 'constituent'}
# {'sentence': 'I know you have made a planned to leave your 9-to-5 job', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'you have made a planned to leave your 9-to-5 job', 'type': 'declarative'}
# {'sentence': 'Plus, I don’t think I barely snacked at all', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I barely snacked at all', 'type': 'declarative'}
# {'sentence': 'I too have been upping the healthy fats in my diet an have definitely noticed that I can last for up to 6 hours without feeling hunger pains!!', 'predicate': [{'str': 'noticed', 'lemma': 'notice', 'POS': 'VERB'}], 'clause': 'that I can last for up to 6 hours without feeling hunger pains', 'type': 'declarative'}
# {'sentence': 'Some people say that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive tract', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive tract', 'type': 'declarative'}
# {'sentence': 'Do you think the 01753476428 was a harass phone number?', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'the 01753476428 was a harass phone number', 'type': 'declarative'}
# {'sentence': 'NationalLedger.com reports that Christina Aguilera risked re-igniting her feud with Britney Spears by a comment made on her wedding day', 'predicate': [{'str': 'reports', 'lemma': 'report', 'POS': 'VERB'}], 'clause': 'that Christina Aguilera risked re-igniting her feud with Britney Spears by a comment made on her wedding day', 'type': 'declarative'}
# {'sentence': 'Christina’s rep denies she made any comment however.', 'predicate': [{'str': 'denies', 'lemma': 'deny', 'POS': 'VERB'}], 'clause': 'she made any comment', 'type': 'declarative'}
# {'sentence': 'In this sense, Mignolo argues that while modernity is not strictly a European phenomenon, its rhetoric -as Dussel argues- is formed by European philosophers, academics and politicians', 'predicate': [{'str': 'argues', 'lemma': 'argue', 'POS': 'VERB'}], 'clause': 'that while modernity is not strictly a European phenomenon, its rhetoric -as Dussel argues- is formed by European philosophers, academics and politicians', 'type': 'declarative'}
# {'sentence': "Business guests appreciate that our downtown hotel's location in Lexington, KY is close to IBM, PNC Bank, Fifth Third Bank, Ashland and UPS", 'predicate': [{'str': 'appreciate', 'lemma': 'appreciate', 'POS': 'VERB'}], 'clause': "that our downtown hotel's location in Lexington, KY is close to IBM, PNC Bank, Fifth Third Bank, Ashland and UPS", 'type': 'declarative'}
# {'sentence': 'AEPi is proud to say that we are one of the loudest Jewish voices on campus', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that we are one of the loudest Jewish voices on campus', 'type': 'declarative'}
# {'sentence': 'On January 31, 2015, The Sacramento Bee reported that the AEPi building in Davis had been tagged with two large swastikas', 'predicate': [{'str': 'reported', 'lemma': 'report', 'POS': 'VERB'}], 'clause': 'that the AEPi building in Davis had been tagged with two large swastikas', 'type': 'declarative'}
# {'sentence': 'I think this is just too cool for school!!!!!', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'this is just too cool for school', 'type': 'declarative'}
# {'sentence': 'With this issue, they said they thought it was a virus and would have it running the next day', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'they thought it was a virus', 'type': 'declarative'}
# {'sentence': 'With this issue, they said they thought it was a virus and would have it running the next day', 'predicate': [{'str': 'thought', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'it was a virus', 'type': 'declarative'}
# {'sentence': 'With this issue, they said they thought it was a virus and would have it running the next day', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'would have it running the next day', 'type': 'declarative'}
# {'sentence': 'Click said that would not be an issue.', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that would not be an issue', 'type': 'declarative'}
# {'sentence': 'I checked in with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'it would be one more day - they were doing some final tests', 'type': 'declarative'}
# {'sentence': 'The next day I learned that they had not put any real time evaluating my laptop and would require a couple more days', 'predicate': [{'str': 'learned', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'that they had not put any real time evaluating my laptop and would require a couple more days', 'type': 'declarative'}
# {'sentence': 'After two more days they said they needed to repair the backlight before trying to determine the other problem', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'they needed to repair the backlight before trying to determine the other problem', 'type': 'declarative'}
# {'sentence': '\u200bDigging a little deeper, we managed to find out that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues.', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}, {'str': 'out', 'lemma': 'out', 'POS': 'ADP'}], 'clause': 'that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues', 'type': 'declarative'}
# {'sentence': "It's interesting to know that Wayne was a co-founder of the Humane Society Legislative Fund", 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that Wayne was a co-founder of the Humane Society Legislative Fund', 'type': 'declarative'}
# {'sentence': "At Radon Fan Guys, we understand that you have to stay within your price range and save cash everywhere you're able to", 'predicate': [{'str': 'understand', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': "that you have to stay within your price range and save cash everywhere you're able to", 'type': 'declarative'}
# {'sentence': 'We use the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'predicate': [{'str': 'ensure', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'type': 'declarative'}
# {'sentence': 'Then he shocked her by declaring that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'predicate': [{'str': 'declaring', 'lemma': 'declare', 'POS': 'VERB'}], 'clause': 'that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'type': 'declarative'}
# {'sentence': 'The Founders Scholarship was created in 2010 by fifteen individuals or couples to ensure that all graduating Mackinac Island students have an opportunity for a multi-year scholarship award', 'predicate': [{'str': 'ensure', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'that all graduating Mackinac Island students have an opportunity for a multi-year scholarship award', 'type': 'declarative'}
# {'sentence': 'The Local Government Association estimates that by 2025, the funding gap will grow to £3bn for children’s social care alone.', 'predicate': [{'str': 'estimates', 'lemma': 'estimate', 'POS': 'VERB'}], 'clause': 'that by 2025, the funding gap will grow to £3bn for children’s social care alone', 'type': 'declarative'}
# {'sentence': 'We are told that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection services', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection services', 'type': 'declarative'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'saying', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that no children will be put in danger as a result of propose cuts', 'type': 'declarative'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'see', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'how this could be the case', 'type': 'constituent'}
# {'sentence': 'But the government is already backing down on this claim, with Jo Farrar, director general to the Ministry of Housing, Communities and Local Government, telling the public accounts committee this week that they do not expect these funds to buy additional capacity', 'predicate': [{'str': 'telling', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'that they do not expect these funds to buy additional capacity', 'type': 'declarative'}
# {'sentence': 'She believes this map will help students complete their homework on time.', 'predicate': [{'str': 'believes', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': 'this map will help students complete their homework on time', 'type': 'declarative'}
# {'sentence': 'In this criminal complaint, the government claims that Khaalid Adam Abdulkadir made death threats against FBI agents in various Twitter posts', 'predicate': [{'str': 'claims', 'lemma': 'claim', 'POS': 'VERB'}], 'clause': 'that Khaalid Adam Abdulkadir made death threats against FBI agents in various Twitter posts', 'type': 'declarative'}
# {'sentence': 'The government agreed that its informant was responsible for first alerting law enforcement to the Twitter communications, but refused disclosure under the government–informant privilege.', 'predicate': [{'str': 'agreed', 'lemma': 'agree', 'POS': 'VERB'}], 'clause': 'that its informant was responsible for first alerting law enforcement to the Twitter communications', 'type': 'declarative'}
# {'sentence': 'The court held that Abdulkadir failed to show that the FBI’s confidential informant was material to his defense', 'predicate': [{'str': 'held', 'lemma': 'hold', 'POS': 'VERB'}], 'clause': 'that Abdulkadir failed to show that the FBI’s confidential informant was material to his defense', 'type': 'declarative'}
# {'sentence': 'The court held that Abdulkadir failed to show that the FBI’s confidential informant was material to his defense', 'predicate': [{'str': 'show', 'lemma': 'show', 'POS': 'VERB'}], 'clause': 'that the FBI’s confidential informant was material to his defense', 'type': 'declarative'}
# {'sentence': 'The court noted that the case remains in the pre-indictment stage, and will permit Abdulkadir to renew his motion at a later date', 'predicate': [{'str': 'noted', 'lemma': 'note', 'POS': 'VERB'}], 'clause': 'that the case remains in the pre-indictment stage', 'type': 'declarative'}
# {'sentence': 'The sting operation, however, allegedly reveals that our personal data may not be totally secure in the hands of a digital payments giant and that it may have sold it to other third-parties out there', 'predicate': [{'str': 'reveals', 'lemma': 'reveal', 'POS': 'VERB'}], 'clause': 'that our personal data may not be totally secure in the hands of a digital payments giant', 'type': 'declarative'}
# {'sentence': 'The sting operation, however, allegedly reveals that our personal data may not be totally secure in the hands of a digital payments giant and that it may have sold it to other third-parties out there', 'predicate': [{'str': 'reveals', 'lemma': 'reveal', 'POS': 'VERB'}], 'clause': 'that it may have sold it to other third-parties out there', 'type': 'declarative'}
# {'sentence': 'Please ensure you revisit this page and re–check for any updates/changes before the date of the fixture.', 'predicate': [{'str': 'ensure', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'you revisit this page and re–check for any updates/changes before the date of the fixture', 'type': 'declarative'}
# {'sentence': 'I know these are just models, but we always like to share them with you', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'these are just models', 'type': 'declarative'}
# {'sentence': 'Many have been speculating that the announcement is for the long awaited next installment in the Persona series', 'predicate': [{'str': 'speculating', 'lemma': 'speculate', 'POS': 'VERB'}], 'clause': 'that the announcement is for the long awaited next installment in the Persona series', 'type': 'declarative'}
# {'sentence': 'You could argue that these elements fall under the category of story, which Persona 3 won anyway, but I feel they are significant enough to make a difference', 'predicate': [{'str': 'argue', 'lemma': 'argue', 'POS': 'VERB'}], 'clause': 'that these elements fall under the category of story, which Persona 3 won anyway', 'type': 'declarative'}
# {'sentence': 'You could argue that these elements fall under the category of story, which Persona 3 won anyway, but I feel they are significant enough to make a difference', 'predicate': [{'str': 'feel', 'lemma': 'feel', 'POS': 'VERB'}], 'clause': 'they are significant enough to make a difference', 'type': 'declarative'}
# {'sentence': 'This is to inform you that you have been selected for a cash prize of £850,000.00 (Eight hundred and fifty thousand Great British Pounds) from the BMW AUTOMOBILE GROUP e-LOTTERY BONANZA International programs held TODAY Teusday the 6th of MARCH 2007, here in London United Kingdom.', 'predicate': [{'str': 'inform', 'lemma': 'inform', 'POS': 'VERB'}], 'clause': 'that you have been selected for a cash prize of £850,000.00 (Eight hundred and fifty thousand Great British Pounds) from the BMW AUTOMOBILE GROUP e-LOTTERY BONANZA International programs held TODAY Teusday the 6th of MARCH 2007, here in London United Kingdom', 'type': 'declarative'}
# {'sentence': 'I think that does a good job of summarising my feelings towards friends who drift away over time.', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'that does a good job of summarising my feelings towards friends who drift away over time', 'type': 'declarative'}
# {'sentence': "According to the Children's Action Network, nationwide each year 20,000 children age out of the foster care system, but experts say they are still in need of a family as they embark on work and college.", 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'they are still in need of a family as they embark on work and college', 'type': 'declarative'}
# {'sentence': 'Executive producer Brandon Margolis revealed that Fletcher, the hacker who helps Mike and Marcus in both films, would also appear in the show.', 'predicate': [{'str': 'revealed', 'lemma': 'reveal', 'POS': 'VERB'}], 'clause': 'that Fletcher, the hacker who helps Mike and Marcus in both films, would also appear in the show', 'type': 'declarative'}
# {'sentence': 'Valentino still loves MotoGP and last year he demonstrated that he still can be competitive', 'predicate': [{'str': 'demonstrated', 'lemma': 'demonstrate', 'POS': 'VERB'}], 'clause': 'he still can be competitive', 'type': 'declarative'}
# {'sentence': "Maverick Vinales admits he was puzzled by why he was uncompetitive on the second day of Valencia's post-season MotoGP test on Wednesday having topped the times on day one.", 'predicate': [{'str': 'admits', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': "he was puzzled by why he was uncompetitive on the second day of Valencia's post-season MotoGP test on Wednesday having topped the times on day one", 'type': 'declarative'}
# {'sentence': "Maverick Vinales admits he was puzzled by why he was uncompetitive on the second day of Valencia's post-season MotoGP test on Wednesday having topped the times on day one.", 'predicate': [{'str': 'puzzled', 'lemma': 'puzzle', 'POS': 'VERB'}, {'str': 'by', 'lemma': 'by', 'POS': 'ADP'}], 'clause': "why he was uncompetitive on the second day of Valencia's post-season MotoGP test on Wednesday having topped the times on day one", 'type': 'constituent'}
# {'sentence': 'Repsol Honda Team Principal Livio Suppo has said that he and Honda aren’t surprised by the pace and performances of new Yamaha recruit Maverick Viñales, but that they are of his team-mate, Valentino Rossi.', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that he and Honda aren’t surprised by the pace and performances of new Yamaha recruit Maverick Viñales, but that they are of his team-mate, Valentino Rossi', 'type': 'declarative'}
# {'sentence': 'Introducing the bill, Law Minister Ravi Shankar Prasad said despite the Supreme Court striking down the practice of talaq-e-biddat (instant triple talaq) as unconstitutional, men were divorcing their wives on flimsy grounds and even via Whatsapp.', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'despite the Supreme Court striking down the practice of talaq-e-biddat (instant triple talaq) as unconstitutional, men were divorcing their wives on flimsy grounds and even via Whatsapp', 'type': 'declarative'}
# {'sentence': "Putin, speaking in International Investments Forum in Sochi, said that Russia's inflation rate would be 7 percent this year.", 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': "that Russia's inflation rate would be 7 percent this year", 'type': 'declarative'}
# {'sentence': "He reminded that in 2009, Russia's GDP dropped by 7.9 percent, inflation reached 9 percent.", 'predicate': [{'str': 'reminded', 'lemma': 'remind', 'POS': 'VERB'}], 'clause': "that in 2009, Russia's GDP dropped by 7.9 percent, inflation reached 9 percent", 'type': 'declarative'}
# {'sentence': 'August was the first month since May when industrial output in Russia was above zero and reaches 0.1 percent, thus Nabiullina called August "a good month", admitting that in agricultural sector growth was negative by 9.6 percent.', 'predicate': [{'str': 'admitting', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': 'that in agricultural sector growth was negative by 9.6 percent', 'type': 'declarative'}
# {'sentence': 'i have ensured that the wireless sync is activated on the handhelds as well', 'predicate': [{'str': 'ensured', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'that the wireless sync is activated on the handhelds as well', 'type': 'declarative'}
# {'sentence': "Firstly, I must say that my comments below are not a criticism of teachers, who work very hard against all the odds, but of education systems that have 'lost their way'", 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': "that my comments below are not a criticism of teachers, who work very hard against all the odds, but of education systems that have 'lost their way'", 'type': 'declarative'}
# {'sentence': "I believe only the chemistry specialist has the 'depth of knowledge' to enthuse the students, which in turn leads to an increased uptake in the subject.", 'predicate': [{'str': 'believe', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': "only the chemistry specialist has the 'depth of knowledge' to enthuse the students, which in turn leads to an increased uptake in the subject", 'type': 'declarative'}
# {'sentence': '74% thought it was too noisy.', 'predicate': [{'str': 'thought', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'it was too noisy', 'type': 'declarative'}
# {'sentence': '81% said the bathroom was dirty.', 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'the bathroom was dirty', 'type': 'declarative'}
# {'sentence': 'Everyone is aware that finding someone close to you can be tiring, so we founded our site with three ideas as our goal: we want to make finding locals easy, mobile, and totally free', 'predicate': [{'str': 'is', 'lemma': 'be', 'POS': 'AUX'}, {'str': 'aware', 'lemma': 'aware', 'POS': 'ADJ'}], 'clause': 'that finding someone close to you can be tiring', 'type': 'declarative'}
# {'sentence': 'Simply adjust your settings and know you will find exactly who you want at the ideal time for you.', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'you will find exactly who you want at the ideal time for you', 'type': 'declarative'}
# {'sentence': 'I’ve been blogging for over three years now, mostly as a passion and I have only became more professional in the recent months but never thought I’d end up making up a start a blog tutorial', 'predicate': [{'str': 'thought', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I’d end up making up a start a blog tutorial', 'type': 'declarative'}
# {'sentence': 'That makes me really happy, I know I had a hard time getting a blog up!', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'I had a hard time getting a blog up', 'type': 'declarative'}
# {'sentence': 'Please note you will be billed a year a time, but as you can see, it works out to a very reasonable monthly amount', 'predicate': [{'str': 'note', 'lemma': 'note', 'POS': 'VERB'}], 'clause': 'you will be billed a year a time', 'type': 'declarative'}
# {'sentence': 'Fill in your billing information, confirm that you’ve read the fine print and then click Next.', 'predicate': [{'str': 'confirm', 'lemma': 'confirm', 'POS': 'VERB'}], 'clause': 'that you’ve read the fine print', 'type': 'declarative'}
# {'sentence': 'I hope my start a blog tutorial has been of help and I look forward to hear your input and also read your new, beautiful blogs', 'predicate': [{'str': 'hope', 'lemma': 'hope', 'POS': 'VERB'}], 'clause': 'my start a blog tutorial has been of help', 'type': 'declarative'}
# {'sentence': 'Irving Azoff Claims YouTube "Pirates" Are "Really Evil"', 'predicate': [{'str': 'Claims', 'lemma': 'claim', 'POS': 'VERB'}], 'clause': 'YouTube "Pirates" Are "Really Evil"', 'type': 'declarative'}
# {'sentence': "Will Someone Explain To The RIAA That SOPA Didn't Pass?", 'predicate': [{'str': 'explain', 'lemma': 'explain', 'POS': 'VERB'}], 'clause': "That SOPA Didn't Pass", 'type': 'declarative'}
# {'sentence': '(Buffalo, NY) – New York State Senator Chris Jacobs announced that he has secured $120,000 in state funding for the twelve branch libraries in the 60th Senate District', 'predicate': [{'str': 'announced', 'lemma': 'announce', 'POS': 'VERB'}], 'clause': 'that he has secured $120,000 in state funding for the twelve branch libraries in the 60th Senate District', 'type': 'declarative'}
# {'sentence': 'Having a graduating senior has finally forced my hand to figure out how to bring our video archives into this new Internets thingy.', 'predicate': [{'str': 'figure', 'lemma': 'figure', 'POS': 'VERB'}, {'str': 'out', 'lemma': 'out', 'POS': 'ADP'}], 'clause': 'how to bring our video archives into this new Internets thingy', 'type': 'constituent'}
# {'sentence': 'I get why there is a Michigan culture that supports hunting and related lifestyle.', 'predicate': [{'str': 'get', 'lemma': 'get', 'POS': 'VERB'}], 'clause': 'why there is a Michigan culture that supports hunting and related lifestyle', 'type': 'constituent'}
# {'sentence': 'Unfortunately, I also understand why there are a very small percentage of zealots who take the guns and rugged independence and separate society to an extreme, and that’s why we end up with groups like the Michigan Militia from the 1990s and now the Hutaree of today.', 'predicate': [{'str': 'understand', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': 'why there are a very small percentage of zealots who take the guns and rugged independence and separate society to an extreme', 'type': 'constituent'}
# {'sentence': 'To get the most beneficial bumper boat, one which is well-made and may last for quite some time, you have to know how to decide on the correct manufacturer.', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'how to decide on the correct manufacturer', 'type': 'constituent'}
# {'sentence': 'You simply need to know how to locate them and evaluate each company.', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'how to locate them and evaluate each company', 'type': 'constituent'}
# {'sentence': 'Query why, exactly, we allow a tax deduction for charitable giving.', 'predicate': [{'str': 'Query', 'lemma': 'query', 'POS': 'VERB'}], 'clause': 'why, exactly, we allow a tax deduction for charitable giving', 'type': 'constituent'}
# {'sentence': 'In this article, we try to understand how people made sense of a family death, within the social contexts of their lives.', 'predicate': [{'str': 'understand', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': 'how people made sense of a family death, within the social contexts of their lives', 'type': 'constituent'}
# {'sentence': 'We discuss how people made sense of the family death in relation to three main contexts: family, religion, and materiality.', 'predicate': [{'str': 'discuss', 'lemma': 'discuss', 'POS': 'VERB'}], 'clause': 'how people made sense of the family death in relation to three main contexts: family, religion, and materiality', 'type': 'constituent'}
# ...
# {'sentence': 'This concerns whether they fall into tax class 1 (mostly applicable to unmarried residents) or tax class 2 (people who are married or in civil partnerships).', 'predicate': [{'str': 'concerns', 'lemma': 'concern', 'POS': 'VERB'}], 'clause': 'whether they fall into tax class 1 (mostly applicable to unmarried residents) or tax class 2 (people who are married or in civil partnerships)', 'type': 'alternative'}
# {'sentence': 'LONDON (AP) \x97 British Prime Minister Theresa May is hunkered down with close allies as she considers whether to give in to relentless pressure to resign, or fight on to save her Brexit plan and her premiership.', 'predicate': [{'str': 'considers', 'lemma': 'consider', 'POS': 'VERB'}], 'clause': 'whether to give in to relentless pressure to resign, or fight on to save her Brexit plan and her premiership', 'type': 'alternative'}
# {'sentence': 'You should check whether the doors are made of solid wood or metal.', 'predicate': [{'str': 'check', 'lemma': 'check', 'POS': 'VERB'}], 'clause': 'whether the doors are made of solid wood or metal', 'type': 'alternative'}
# {'sentence': 'I almost asked whether she\x92d been stabbed in a literal or metaphorical Barcelona, but it sounded snide so I didn\x92t say anything.', 'predicate': [{'str': 'asked', 'lemma': 'ask', 'POS': 'VERB'}], 'clause': 'whether she\x92d been stabbed in a literal or metaphorical Barcelona', 'type': 'alternative'}
# {'sentence': 'The other two cats stood poised nearby, as if undecided on whether to back up their fellow or choose the better part of valor.', 'predicate': [{'str': 'undecided', 'lemma': 'undecided', 'POS': 'ADJ'}, {'str': 'on', 'lemma': 'on', 'POS': 'ADP'}], 'clause': 'whether to back up their fellow or choose the better part of valor', 'type': 'alternative'}
# {'sentence': 'CFIUS would have 30 days to decide whether to require a full formal filing or determine that no further action is necessary.', 'predicate': [{'str': 'decide', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether to require a full formal filing or determine that no further action is necessary', 'type': 'alternative'}
# {'sentence': 'CFIUS would have 30 days to decide whether to require a full formal filing or determine that no further action is necessary.', 'predicate': [{'str': 'determine', 'lemma': 'determine', 'POS': 'VERB'}], 'clause': 'that no further action is necessary', 'type': 'declarative'}
# {'sentence': 'It is difficult to predict whether the Supreme Court\x92s grant of certiorari in Bilski signals an intent to significantly narrow or expand the scope of patent eligibility under 35 U.S.C.', 'predicate': [{'str': 'predict', 'lemma': 'predict', 'POS': 'VERB'}], 'clause': 'whether the Supreme Court\x92s grant of certiorari in Bilski signals an intent to significantly narrow or expand the scope of patent eligibility under 35 U.S.C.', 'type': 'alternative'}
# {'sentence': 'Additional studies are needed to clarify whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein.', 'predicate': [{'str': 'clarify', 'lemma': 'clarify', 'POS': 'VERB'}], 'clause': 'whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein', 'type': 'alternative'}
# {'sentence': 'Deciding whether you should join a team or go at it alone will have a significant impact on your success.', 'predicate': [{'str': 'Deciding', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether you should join a team or go at it alone', 'type': 'alternative'}
# {'sentence': 'Sources do not say whether he worked for a shipping company or for a government agency, such as the Federal Maritime Commission or the New York Port Authority.', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'whether he worked for a shipping company or for a government agency, such as the Federal Maritime Commission or the New York Port Authority', 'type': 'alternative'}
# {'sentence': 'To find out whether Intertops is as strong as ever, or is beginning to show its age, check out the rest of our review.', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}, {'str': 'out', 'lemma': 'out', 'POS': 'ADP'}], 'clause': 'whether Intertops is as strong as ever, or is beginning to show its age', 'type': 'alternative'}
# {'sentence': 'The scope of processing personal data primarily depends on whether a user simply visits one of our websites, uses them as a registered user or is just registering.', 'predicate': [{'str': 'depends', 'lemma': 'depend', 'POS': 'VERB'}, {'str': 'on', 'lemma': 'on', 'POS': 'ADP'}], 'clause': 'whether a user simply visits one of our websites, uses them as a registered user or is just registering', 'type': 'alternative'}
# {'sentence': 'reCAPTCHA is designed to check whether data is entered on our websites by a human or by automated software, e.g.', 'predicate': [{'str': 'check', 'lemma': 'check', 'POS': 'VERB'}], 'clause': 'whether data is entered on our websites by a human or by automated software, e.g.', 'type': 'alternative'}
# {'sentence': 'So I called Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it.', 'predicate': [{'str': 'asked', 'lemma': 'ask', 'POS': 'VERB'}], 'clause': 'whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it', 'type': 'alternative'}
# {'sentence': 'We just have to guess whether the card on the card on the player or the banker who will be the winner, or the game ends in a tie.', 'predicate': [{'str': 'guess', 'lemma': 'guess', 'POS': 'VERB'}], 'clause': 'whether the card on the card on the player or the banker who will be the winner', 'type': 'alternative'}
# {'sentence': 'For centuries Jewish villages had to decide whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry.', 'predicate': [{'str': 'decide', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry', 'type': 'alternative'}
# {'sentence': 'You can\x92t easily configure whether you want the video to be oriented horizontally (landscape) or vertically (portrait).', 'predicate': [{'str': 'configure', 'lemma': 'configure', 'POS': 'VERB'}], 'clause': 'whether you want the video to be oriented horizontally (landscape) or vertically (portrait)', 'type': 'alternative'}
# {'sentence': 'This includes the rights to property, the ability to raise children, and whether you will pay or receive alimony.', 'predicate': [{'str': 'includes', 'lemma': 'include', 'POS': 'VERB'}], 'clause': 'whether you will pay or receive alimony', 'type': 'alternative'}
# {'sentence': "I've gone back and forth on whether Desire or BOTT is my favorite Dylan record (with Blonde on Blonde working it's way in there from time to time).", 'predicate': [{'str': 'gone', 'lemma': 'go', 'POS': 'VERB'}, {'str': 'on', 'lemma': 'on', 'POS': 'ADP'}], 'clause': 'whether Desire or BOTT is my favorite Dylan record', 'type': 'alternative'}
# {'sentence': 'What difference does it make whether Jesus or the Holy Spirit lives in my heart?\x94.', 'predicate': [{'str': 'make', 'lemma': 'make', 'POS': 'VERB'}], 'clause': 'whether Jesus or the Holy Spirit lives in my heart', 'type': 'alternative'}
# ["Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.", 'I have always loved fashion and believe that it plays an integral role in self expression', 'Being a Conroe and Woodlands Family Photographer, I find that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions)', 'I can honestly say that that is precisely what happened on this day', 'I have decided that I want her to be my pen pal and take it back old school', 'They were up for something different and an adventure, so I felt it was a great opportunity to shoot in!', 'I am also praying that everyone who flooded is doing ok and things are getting back to normal!', 'I also should mention that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session.', 'This is not to say that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'When we laid our foundation stone in Denver, CO 80211 almost 10 years ago, we realized that the people of the city have been desperately missing the services of a professional locksmith company', 'For anyone following Tiny Tim’s adventures, we know that he lives with his mum and has never met his real dad', "@avoto hm, I don't think that it's a good idea", '@PaulMaly_twitter I was thinking that there can be more than one version where one is is the Ractive component file as per the official spec', 'I think the components should be written so that they could work without any compilation at least in one environment', 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'Here I argue that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed', 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'Yet, if we deny that Jones’ life has any real meaning because his pain outweighs his enjoyment of life then his worth is reduced to the sum total of the pain or the pleasure he is experiencing', 'Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)', 'My parents have worked all of their lives and they always told me whether it is just a part-time job, a volunteer job, or your career, if you agreed to work for someone, do just that.', 'It is to admit that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them.', 'However, defining mercy solely as relationship might indicate that euthanasia is not incompatible with mercy', 'However, to accept this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'News BREAKING: HHA owner Jon Kelly has revealed he was sacked on Monday as administrators Ferrier Hodgson announced the business was in voluntary administration.', "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, ...
# ['Shower Doors is a relatively small company that can offer you more personalized service, which is something not offered by many companies today.', 'Hardware is very well made, offering a diverse selection of style and color', 'Hardware is very durable and offers you many years of trouble free operation.', "He has only just become a free agent, but if this report is true then he will have many former teammates to play with, including Lucas 'LUCAS1' Teles, Henrique 'HEN1' Teles, and Lucas 'steel' Lopes.", 'Now that you know your priorities and price range, use the criteria to narrow your home search', 'Start with my Featured Listings to see examples of beautiful North Shore homes', 'Contact me to arrange a personal showing of any home in the North Shore area!', 'We took to the only wildflower field that I could find this year, which was in Huntsville', 'The park itself is just so beautiful and compliments my Outdoor Family Photography Woodlands session collection so nicely', 'I love the rich colors it has to offer and the beautiful family that I was able to photograph', 'No complaining here!!!', 'Tweet Me if You Love Me!', 'If you’d like to learn more about my sessions, click here', 'And to get in touch, ask questions, or just say hi.', 'drop me a line', 'I’d love to hear from you.', 'If you are self conscious about your arms, wear sleeves.', 'If you don’t like dresses, don’t wear one!', 'If your husband doesn’t love suspenders and has never worn them a day in his life, please leave those at the store', 'So if you aren’t one to dress in a cowboy hat and boots then why would you for a photo shoot', 'Just don’t do it', 'If you love white and jeans, find different styles of white shirts and different tones of blue jeans (dark, weathered, light, etc)', 'This is all great information, but where do you get all these dreamy clothes?', 'And if you do not want to purchase clothing, I do have a few clothing options if you’d like to come to the studio to take a look.', 'My goal is to document your life the way your kids sees it, and the way you want to be remembered.', 'when you click with your clients, magic kind of happens', 'I clicked with this beautiful family and found a new friend in this little 4 year old', 'My family and I have had an interesting couple of weeks, to say the least', 'My husband graduated (HOORAY!) from Sam Houston after a long time of blood, sweat, and tears', 'We took to a location I had my eyes on for about a year', 'I was waiting for the perfect type of session to take to this specific place', 'Aubrie was a sleep fighter of champs but we managed to get a few minutes of her sleeping on her belly towards the end of her The Woodlands Newborn Studio session', 'Below are summaries of the crashes of the seriously injured or fatally inured person who were not listed as in error of traveling in the wrong lane or crossing the center line', 'Of course all incident reports are not final and do not represent proof of fault of any driver', 'In each of these collisions as reported by the MSHP a vehicle crossed the center line and struck another vehicle head-on or in several instances, a driver was driving the wrong way on a highway and then struck another vehicle head-on', 'Louis, MO woman and an 18 year-old Hannibal, MO woman were both seriously injured when a Toyota Matrix driven by an 18 year-old Country Club Hills, IL man crossed the center line and struck their Mazda.', 'February 17, 2019, Adair County, Hwy 6: A 34 year-old Brashear, MO man was seriously injured along with his 10 year-old son when a 28 year-old Canton, MO man crossed the center line on icy highway and struck their Jeep head-on', 'The 28 year-old driver of the Ford truck was also seriously injured.', 'March 25, 2019; Stone County, MO 143: An 82 year-old Crane, MO woman was killed when her Chevy HHR was struck head-on by a Ford Ranger driven by a 68 year-old Marionville, MO man', 'March 27, 2019, Christian County, US 6: A 67 year-old Reeds Spring, MO man  ...

# %%
#get verb list from MegaAcceptability
mega = pd.read_csv('mega-acceptability-v2\mega-acceptability-v2.tsv', sep='\t', header=0)
mega_verbs = mega['verb'].unique()

mega_singles = []
mega_doubles = []

for v in mega_verbs:
    if "_" in v:
        mega_doubles.append(v.split("_"))
    else:
        mega_singles.append(v)

print(mega_singles)
print(mega_doubles)

for d in mega_doubles:
    print(d)

doubles_end = [m[1] for m in mega_doubles]
doubles_start = [m[0] for m in mega_doubles]
# Out:
# ['abhor', 'absolve', 'accept', 'acclaim', 'accredit', 'acknowledge', 'add', 'address', 'admire', 'admit', 'admonish', 'adore', 'advertise', 'advise', 'advocate', 'affect', 'affirm', 'afford', 'affront', 'aggravate', 'aggrieve', 'agitate', 'agonize', 'agree', 'aim', 'alarm', 'alert', 'allege', 'allow', 'alter', 'amaze', 'amuse', 'analyze', 'anger', 'anguish', 'annotate', 'announce', 'annoy', 'answer', 'anticipate', 'apologize', 'appall', 'appeal', 'appear', 'appease', 'applaud', 'apply', 'appoint', 'appraise', 'appreciate', 'approach', 'approve', 'argue', 'arouse', 'arrange', 'articulate', 'ascertain', 'ask', 'assert', 'assess', 'assign', 'assume', 'assure', 'astonish', 'astound', 'attempt', 'attest', 'audit', 'authorize', 'awe', 'babble', 'back', 'badger', 'baffle', 'bandy', 'banter', 'bargain', 'bark', 'be', 'beam', 'bear', 'befuddle', 'beg', 'begin', 'believe', 'belittle', 'bellow', 'beseech', 'bet', 'bewilder', 'bicker', 'bitch', 'blame', 'blare', 'blast', 'bleat', 'bless', 'blog', 'bluff', 'bluster', 'boast', 'boggle', 'bore', 'bother', 'brag', 'brainstorm', 'bribe', 'brief', 'broadcast', 'brood', 'bug', 'bullshit', 'bully', 'bury', 'buy', 'cackle', 'cajole', 'calculate', 'calibrate', 'call', 'calm', 'care', 'carp', 'catch', 'categorize', 'cause', 'caution', 'cease', 'celebrate', 'censor', 'censure', 'certify', 'challenge', 'change', 'chant', 'characterize', 'charge', 'charm', 'chasten', 'chastise', 'chat', 'chatter', 'check', 'cheer', 'cherish', 'chide', 'chime', 'chirp', 'choose', 'chronicle', 'chuckle', 'circulate', 'claim', 'clarify', 'classify', 'clear', 'cloud', 'coach', 'coax', 'coerce', 'come', 'comfort', 'command', 'commence', 'commend', 'comment', 'commission', 'communicate', 'compel', 'compete', 'complain', 'compliment', 'comprehend', 'compromise', 'compute', 'conceal', 'concede', 'conceive', 'concern', 'conclude', 'concur', 'condemn', 'condone', 'confess', 'confide', 'configure', 'confirm', 'confound', 'confuse', 'congratulate', 'conjecture', 'connect', 'consent', 'consider', 'console', 'conspire', 'constrain', 'consult', 'contact', 'contemplate', 'contend', 'content', 'contest', 'continue', 'contract', 'contribute', 'contrive', 'control', 'convey', 'convince', 'correct', 'corroborate', 'cough', 'counsel', 'counter', 'cover', 'crack', 'crave', 'credential', 'cringe', 'criticize', 'croak', 'croon', 'crow', 'crush', 'cry', 'curse', 'dare', 'daunt', 'daydream', 'daze', 'debate', 'deceive', 'decide', 'declare', 'decline', 'decree', 'decry', 'deduce', 'deem', 'defend', 'define', 'deject', 'delete', 'deliberate', 'delight', 'delineate', 'delude', 'demand', 'demean', 'demonstrate', 'demoralize', 'demystify', 'denounce', 'deny', 'depict', 'deplore', 'depress', 'deride', 'derive', 'describe', 'deserve', 'design', 'designate', 'desire', 'despair', 'despise', 'detail', 'detect', 'determine', 'detest', 'devastate', 'devise', 'diagnose', 'dictate', 'dig', 'direct', 'disagree', 'disallow', 'disappoint', 'disapprove', 'disbelieve', 'discern', 'discipline', 'disclose', 'disconcert', 'discourage', 'discover', 'discriminate', 'discuss', 'disgrace', 'disgruntle', 'disgust', 'dishearten', 'disillusion', 'dislike', 'dismay', 'dismiss', 'disparage', 'dispatch', 'dispel', 'dispirit', 'display', 'displease', 'disprefer', 'disprove', 'dispute', 'disquiet', 'disregard', 'dissatisfy', 'dissent', 'distract', 'distress', 'distrust', 'disturb', 'dither', 'divulge', 'document', 'doubt', 'draw', 'drawl', 'dread', 'dream', 'drone', 'dub', 'dupe', 'educate', 'elaborate', 'elate', 'elect', 'electrify', 'elucidate', 'email', 'embarrass', 'embellish', 'embitter', 'embolden', 'emphasize', 'employ', 'enchant', 'encourage', 'end', 'endorse', 'endure', 'energize', 'enforce', 'engage', 'enjoy', 'enlighten', 'enlist', 'enrage', 'ensure', 'enthrall', 'enthuse', 'entice', 'entreat', 'envision', 'envy', 'establish', 'estimate', 'evaluate', 'evidence', 'examine', 'exasperate', 'excite', 'exclaim', 'excuse', 'exhibit', 'exhilarate', 'expect', 'experience', ' ...
# [['come', 'around'], ['come', 'out'], ['fess', 'up'], ['figure', 'out'], ['find', 'out'], ['flip', 'out'], ['freak', 'out'], ['hush', 'up'], ['make', 'out'], ['piece', 'together'], ['point', 'out'], ['reason', 'out'], ['set', 'about'], ['set', 'out'], ['shut', 'up'], ['sign', 'on'], ['sign', 'up'], ['start', 'off'], ['turn', 'out']]
# ['come', 'around']
# ['come', 'out']
# ['fess', 'up']
# ['figure', 'out']
# ['find', 'out']
# ['flip', 'out']
# ['freak', 'out']
# ['hush', 'up']
# ['make', 'out']
# ['piece', 'together']
# ['point', 'out']
# ['reason', 'out']
# ['set', 'about']
# ['set', 'out']
# ['shut', 'up']
# ['sign', 'on']
# ['sign', 'up']
# ['start', 'off']
# ['turn', 'out']

# %%
#verb matching - the baseline heuristics
verb_matcher = Matcher(nlp.vocab)

verb_patterns = []
#SINGLES = ["believe", "think", "know", "wonder", "hope", "fear", "like", "regret", "see", "ask", "say", "tell", "check", "decide", "determine", "consider"]
#DOUBLES = ["certain", "happy", "curious"]
SINGLES = mega_singles
DOUBLES = mega_doubles

for sing in SINGLES:
  pattern = [{"LEMMA": sing, "POS": "VERB"}]
  verb_patterns.append(pattern)

#for doub in DOUBLES:
#  pattern = [{"LEMMA": "be", "POS": "AUX"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}, {"LEMMA": doub}]
#  verb_patterns.append(pattern)
for doub in DOUBLES:
  pattern = [{"LEMMA": doub[0], "POS": "AUX"}, {"OP": "?"}, {"OP": "?"}, {"OP": "?"}, {"LEMMA": doub[1]}]
  verb_patterns.append(pattern)


verb_matcher.add("embedding_verb", verb_patterns)

#clause matching
clause_matcher = Matcher(nlp.vocab)
pattern_d = [{"TEXT": "that", "POS": "SCONJ"}]
clause_matcher.add("declarative", [pattern_d])

pattern_i1 = [{"TEXT": "whether", "POS": "SCONJ"}]
clause_matcher.add("polar", [pattern_i1])

pattern_c1 = [{"TEXT": "who"}]
pattern_c2 = [{"TEXT": "what"}]
pattern_c3 = [{"TEXT": "when"}]
pattern_c4 = [{"TEXT": "where"}]
pattern_c5 = [{"TEXT": "why"}]
pattern_c6 = [{"TEXT": "how"}]
pattern_c7 = [{"TEXT": "which"}]
clause_matcher.add("constituent", [pattern_c1, pattern_c2, pattern_c3, pattern_c4, pattern_c5, pattern_c6, pattern_c7])


#this function takes nlp("sentence") as input and prints annotations
def get_baseline(sent, print_negs = False):
  embeddings = []
  embedded_clauses = []

  #get embedding predicates
  verb_matches = verb_matcher(sent)
  for match_id, start, end in verb_matches:
      emb = dict.fromkeys(["sentence", "predicate", "clause", "type"])
      full_pred = []

      #default values for sentence and for predicate annotation
      emb["sentence"] = sent.text
      full_pred.append({"str": sent[start].text, "lemma": sent[start].lemma_, 'POS': sent[start].pos_})
      
      #doubles values for predicate annotation
      if (sent[start].text in doubles_start) and (sent[end-1].text in doubles_end):
        full_pred.append({"str": sent[end-1].text, "lemma": sent[end-1].lemma_, 'POS': sent[end-1].pos_})

      #edge cases where there is a preposition, adverb, pronoun, or noun between the verb and the clause
      if (len(sent) > end) and (sent[end].pos_ == "ADP"):
        full_pred.append({"str": sent[end].text, "lemma": sent[end].lemma_, 'POS': sent[end].pos_})
        end += 1

      if (len(sent) > end) and (sent[end].pos_ in ["ADV", "PRON", "PROPN"]) and (not end < len(sent)) and (sent[end+1].pos_ in ["SCONJ", "PRON"]):
        end += 1

      emb["predicate"] = full_pred


      #get the potential clause
      clause = sent[end:]
      if len(clause) < 1:
        continue
      if clause[-1].is_punct:
        clause = clause[:-1]
      emb["clause"] = clause.text

      #find clause type
      clause_matches = clause_matcher(clause)
      clause_pos = [token.pos_ for token in clause]

      for match_id, start, end in clause_matches:
        clause_type = nlp.vocab.strings[match_id]
        emb["type"] = clause_type

        #separate polars from alternatives
        if clause_type == "polar":
          if (" or " in clause.text) and not (" or not " in clause.text) and not (" or not." in sent[end:].text):
            emb["type"] = "alternative"

        break

      #type declaraties without marks
      if clause_matches == [] and (clause_pos.count("VERB") ==1 or clause_pos.count("AUX") ==1):
        emb["type"] = "declarative"

      #if it was a genuine embedded clause add to the sentence's set of annotations
      if emb["type"] != None:
        embedded_clauses.append(emb)



  if embedded_clauses != []:
    for e in embedded_clauses:
      print(e)
      embeddings.append(e)

  elif print_negs == True:
    embeddings.append({'sentence': sent, 'predicate': [], 'clause': '', 'type': ''})
    print({'sentence': sent, 'predicate': [], 'clause': '', 'type': ''})

  return embeddings

# %%
#running baseline on golden sets
baseline_results = []
for s in gold_sentences:
  my_sent = nlp(s)
  outs = get_baseline(my_sent, print_negs = False)
  baseline_results += outs
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# {'sentence': "Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.", 'predicate': [{'str': 'recruit', 'lemma': 'recruit', 'POS': 'VERB'}], 'clause': "a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel", 'type': 'declarative'}
# {'sentence': "Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.", 'predicate': [{'str': 'GO', 'lemma': 'go', 'POS': 'VERB'}], 'clause': "player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel", 'type': 'declarative'}
# {'sentence': "Luminosity Gaming may be about to recruit a new CS:GO player, as VPEsports reports that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel.", 'predicate': [{'str': 'reports', 'lemma': 'report', 'POS': 'VERB'}], 'clause': "that Ricardo 'boltz' Prass is set to rejoin the side to replace Gustavo 'yeL' Knittel", 'type': 'declarative'}
# {'sentence': 'I have always loved fashion and believe that it plays an integral role in self expression', 'predicate': [{'str': 'loved', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'fashion and believe that it plays an integral role in self expression', 'type': 'declarative'}
# {'sentence': 'I have always loved fashion and believe that it plays an integral role in self expression', 'predicate': [{'str': 'believe', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': 'that it plays an integral role in self expression', 'type': 'declarative'}
# {'sentence': 'Being a Conroe and Woodlands Family Photographer, I find that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions)', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'that emotions are the most noticeable thing in my photographs (especially since I shoot with a candid approach to my sessions', 'type': 'declarative'}
# {'sentence': 'I can honestly say that that is precisely what happened on this day', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that that is precisely what happened on this day', 'type': 'declarative'}
# {'sentence': 'I have decided that I want her to be my pen pal and take it back old school', 'predicate': [{'str': 'decided', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'that I want her to be my pen pal and take it back old school', 'type': 'declarative'}
# {'sentence': 'I have decided that I want her to be my pen pal and take it back old school', 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'her to be my pen pal and take it back old school', 'type': 'declarative'}
# {'sentence': 'They were up for something different and an adventure, so I felt it was a great opportunity to shoot in!', 'predicate': [{'str': 'felt', 'lemma': 'feel', 'POS': 'VERB'}], 'clause': 'it was a great opportunity to shoot in', 'type': 'declarative'}
# {'sentence': 'I am also praying that everyone who flooded is doing ok and things are getting back to normal!', 'predicate': [{'str': 'praying', 'lemma': 'pray', 'POS': 'VERB'}], 'clause': 'that everyone who flooded is doing ok and things are getting back to normal', 'type': 'declarative'}
# {'sentence': 'I also should mention that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session.', 'predicate': [{'str': 'mention', 'lemma': 'mention', 'POS': 'VERB'}], 'clause': 'that Eurri Farris, of Eurri Kim Photography was an amazing help that day, assisting in this session', 'type': 'declarative'}
# {'sentence': 'This is not to say that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that any one of these reasons were the cause or causes of any of the head-on collisions in Missouri in the last three months', 'type': 'declarative'}
# {'sentence': 'When we laid our foundation stone in Denver, CO 80211 almost 10 years ago, we realized that the people of the city have been desperately missing the services of a professional locksmith company', 'predicate': [{'str': 'realized', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'that the people of the city have been desperately missing the services of a professional locksmith company', 'type': 'declarative'}
# {'sentence': 'For anyone following Tiny Tim’s adventures, we know that he lives with his mum and has never met his real dad', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that he lives with his mum and has never met his real dad', 'type': 'declarative'}
# {'sentence': "@avoto hm, I don't think that it's a good idea", 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': "that it's a good idea", 'type': 'declarative'}
# {'sentence': '@PaulMaly_twitter I was thinking that there can be more than one version where one is is the Ractive component file as per the official spec', 'predicate': [{'str': 'thinking', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'that there can be more than one version where one is is the Ractive component file as per the official spec', 'type': 'declarative'}
# {'sentence': 'I think the components should be written so that they could work without any compilation at least in one environment', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'the components should be written so that they could work without any compilation at least in one environment', 'type': 'declarative'}
# {'sentence': 'I think the components should be written so that they could work without any compilation at least in one environment', 'predicate': [{'str': 'written', 'lemma': 'write', 'POS': 'VERB'}], 'clause': 'so that they could work without any compilation at least in one environment', 'type': 'declarative'}
# {'sentence': 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'predicate': [{'str': 'trust', 'lemma': 'trust', 'POS': 'VERB'}], 'clause': 'me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'type': 'constituent'}
# {'sentence': 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'type': 'declarative'}
# {'sentence': 'All right, I was really bad at photographing this weekend, but just trust me when I say that it was filled with good things: fireplaces, hot apple cider, laughs, the picture game, a skype date with my brother, exploring, and, and, and', 'predicate': [{'str': 'laughs', 'lemma': 'laugh', 'POS': 'VERB'}], 'clause': ', the picture game, a skype date with my brother, exploring, and, and, and', 'type': 'declarative'}
# {'sentence': 'Here I argue that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed', 'predicate': [{'str': 'argue', 'lemma': 'argue', 'POS': 'VERB'}], 'clause': 'that despite the good intentions of euthanasia advocates, their understanding of mercy is flawed', 'type': 'declarative'}
# {'sentence': 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'predicate': [{'str': 'believe', 'lemma': 'believe', 'POS': 'VERB'}], 'clause': 'that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'type': 'declarative'}
# {'sentence': 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'predicate': [{'str': 'taking', 'lemma': 'take', 'POS': 'VERB'}], 'clause': 'the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'type': 'constituent'}
# {'sentence': 'Euthanasia advocates believe that intentionally taking the life of someone who is terminally ill or suffering severe pain constitutes an act of mercy', 'predicate': [{'str': 'suffering', 'lemma': 'suffer', 'POS': 'VERB'}], 'clause': 'severe pain constitutes an act of mercy', 'type': 'declarative'}
# {'sentence': 'Yet, if we deny that Jones’ life has any real meaning because his pain outweighs his enjoyment of life then his worth is reduced to the sum total of the pain or the pleasure he is experiencing', 'predicate': [{'str': 'deny', 'lemma': 'deny', 'POS': 'VERB'}], 'clause': 'that Jones’ life has any real meaning because his pain outweighs his enjoyment of life then his worth is reduced to the sum total of the pain or the pleasure he is experiencing', 'type': 'declarative'}
# {'sentence': 'Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)', 'predicate': [{'str': 'holds', 'lemma': 'hold', 'POS': 'VERB'}], 'clause': 'that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047', 'type': 'declarative'}
# {'sentence': 'Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)', 'predicate': [{'str': 'forces', 'lemma': 'force', 'POS': 'VERB'}], 'clause': 'us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047', 'type': 'constituent'}
# {'sentence': 'Ethics academic Gilbert Meilaender holds that such thinking forces us to speak of ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047)', 'predicate': [{'str': 'speak', 'lemma': 'speak', 'POS': 'VERB'}, {'str': 'of', 'lemma': 'of', 'POS': 'ADP'}], 'clause': 'ourselves in terms of “what we have” instead of “who we are” (http://www.firstthings.com/article.php3?id_article=6047', 'type': 'constituent'}
# {'sentence': 'My parents have worked all of their lives and they always told me whether it is just a part-time job, a volunteer job, or your career, if you agreed to work for someone, do just that.', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'me whether it is just a part-time job, a volunteer job, or your career, if you agreed to work for someone, do just that', 'type': 'alternative'}
# {'sentence': 'It is to admit that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them.', 'predicate': [{'str': 'admit', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': 'that doctors are in some way divorced from their patients and unaffected by the treatment they provide to them', 'type': 'declarative'}
# {'sentence': 'However, defining mercy solely as relationship might indicate that euthanasia is not incompatible with mercy', 'predicate': [{'str': 'defining', 'lemma': 'define', 'POS': 'VERB'}], 'clause': 'mercy solely as relationship might indicate that euthanasia is not incompatible with mercy', 'type': 'declarative'}
# {'sentence': 'However, defining mercy solely as relationship might indicate that euthanasia is not incompatible with mercy', 'predicate': [{'str': 'indicate', 'lemma': 'indicate', 'POS': 'VERB'}], 'clause': 'that euthanasia is not incompatible with mercy', 'type': 'declarative'}
# {'sentence': 'However, to accept this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'predicate': [{'str': 'accept', 'lemma': 'accept', 'POS': 'VERB'}], 'clause': 'this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'type': 'declarative'}
# {'sentence': 'However, to accept this definition of relationship is to admit that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'predicate': [{'str': 'admit', 'lemma': 'admit', 'POS': 'VERB'}], 'clause': 'that a doctor who provides Jones with a lethal injection acts in a way that is morally equivalent to a doctor who nurses Jones to his death', 'type': 'declarative'}
# {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': [{'str': 'Thinking', 'lemma': 'think', 'POS': 'VERB'}, {'str': 'about', 'lemma': 'about', 'POS': 'ADP'}], 'clause': 'Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love', 'type': 'declarative'}
# {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': [{'str': 'writes', 'lemma': 'write', 'POS': 'VERB'}], 'clause': ': “Often, we learn that something is precious only when we see it in the light of someone’s love', 'type': 'declarative'}
# {'sentence': 'In A Common Humanity: Thinking about Love and Truth and Justice (2000) Gaita writes: “Often, we learn that something is precious only when we see it in the light of someone’s love”', 'predicate': [{'str': 'learn', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'that something is precious only when we see it in the light of someone’s love', 'type': 'declarative'}
# {'sentence': 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'predicate': [{'str': 'loving', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'type': 'declarative'}
# {'sentence': 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'predicate': [{'str': 'seeing', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'that Jones is loved, we realise Jones to be a person with inherent dignity', 'type': 'declarative'}
# {'sentence': 'Therefore, by loving Jones or by seeing that Jones is loved, we realise Jones to be a person with inherent dignity', 'predicate': [{'str': 'loved', 'lemma': 'love', 'POS': 'VERB'}], 'clause': ', we realise Jones to be a person with inherent dignity', 'type': 'declarative'}
# {'sentence': 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'predicate': [{'str': 'saying', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'type': 'declarative'}
# {'sentence': 'A new report is saying that new car sales took a nosedive in September, signaling economic distress could be just around the corner', 'predicate': [{'str': 'took', 'lemma': 'take', 'POS': 'VERB'}], 'clause': 'a nosedive in September, signaling economic distress could be just around the corner', 'type': 'declarative'}
# {'sentence': 'News BREAKING: HHA owner Jon Kelly has revealed he was sacked on Monday as administrators Ferrier Hodgson announced the business was in voluntary administration.', 'predicate': [{'str': 'announced', 'lemma': 'announce', 'POS': 'VERB'}], 'clause': 'the business was in voluntary administration', 'type': 'declarative'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'like', 'lemma': 'like', 'POS': 'VERB'}], 'clause': "to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013", 'type': 'declarative'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': "that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013", 'type': 'declarative'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'contributing', 'lemma': 'contribute', 'POS': 'VERB'}, {'str': 'in', 'lemma': 'in', 'POS': 'ADP'}], 'clause': 'my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013', 'type': 'constituent'}
# {'sentence': "“Professor Carter's research is so important in preserving the planet, and I'd like to think that I'm contributing in my own small way,” said Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013.", 'predicate': [{'str': 'said', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'Baughman, who worked at Firestone Library from 2006 to 2008 and returned to Princeton in 2013', 'type': 'constituent'}
# {'sentence': 'Did I forget to mention the home has 3 zone heat and Air conditioning on 1.8 acres of property on a no thruway street', 'predicate': [{'str': 'mention', 'lemma': 'mention', 'POS': 'VERB'}], 'clause': 'the home has 3 zone heat and Air conditioning on 1.8 acres of property on a no thruway street', 'type': 'declarative'}
# {'sentence': 'Ready-made Greens can be useful for mixing other colours too, we’re not suggesting you should chuck them out!', 'predicate': [{'str': 'suggesting', 'lemma': 'suggest', 'POS': 'VERB'}], 'clause': 'you should chuck them out', 'type': 'declarative'}
# {'sentence': 'You will see that small differences in the amount of black can make a big difference to the colour you make.', 'predicate': [{'str': 'see', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'that small differences in the amount of black can make a big difference to the colour you make', 'type': 'declarative'}
# {'sentence': 'You will see that small differences in the amount of black can make a big difference to the colour you make.', 'predicate': [{'str': 'make', 'lemma': 'make', 'POS': 'VERB'}], 'clause': 'a big difference to the colour you make', 'type': 'declarative'}
# {'sentence': 'One study found that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'predicate': [{'str': 'found', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin', 'type': 'declarative'}
# {'sentence': 'One study found that variations in the serotonin transporter gene influence whether or not a person will respond to an antidepressant such as an SSRI, which acts upon serotonin.', 'predicate': [{'str': 'respond', 'lemma': 'respond', 'POS': 'VERB'}, {'str': 'to', 'lemma': 'to', 'POS': 'ADP'}], 'clause': 'an antidepressant such as an SSRI, which acts upon serotonin', 'type': 'constituent'}
# {'sentence': 'I have so many things I want to write about I fear I’m bursting at the seams', 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'to write about I fear I’m bursting at the seams', 'type': 'declarative'}
# {'sentence': 'I have so many things I want to write about I fear I’m bursting at the seams', 'predicate': [{'str': 'write', 'lemma': 'write', 'POS': 'VERB'}, {'str': 'about', 'lemma': 'about', 'POS': 'ADP'}], 'clause': 'I fear I’m bursting at the seams', 'type': 'declarative'}
# {'sentence': 'I have so many things I want to write about I fear I’m bursting at the seams', 'predicate': [{'str': 'fear', 'lemma': 'fear', 'POS': 'VERB'}], 'clause': 'I’m bursting at the seams', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'HEAR', 'lemma': 'hear', 'POS': 'VERB'}], 'clause': 'THAT??” And I look at C’s dad and he’s saying the same', 'type': 'declarative'}
# {'sentence': 'I think I was so stunned that it was meant for him that I didn’t get it at first, until my friend hit me hard in the leg and she said to me “Did YOU HEAR THAT??” And I look at C’s dad and he’s saying the same', 'predicate': [{'str': 'look', 'lemma': 'look', 'POS': 'VERB'}, {'str': 'at', 'lemma': 'at', 'POS': 'ADP'}], 'clause': 'C’s dad and he’s saying the same', 'type': 'declarative'}
# {'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': [{'str': 'is', 'lemma': 'be', 'POS': 'VERB'}], 'clause': 'such a mixture he understands that he can do so much more then he thought he could', 'type': 'declarative'}
# {'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': [{'str': 'understands', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': 'that he can do so much more then he thought he could', 'type': 'declarative'}
# {'sentence': 'In these classes there is such a mixture he understands that he can do so much more then he thought he could.', 'predicate': [{'str': 'thought', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'he could', 'type': 'declarative'}
# {'sentence': 'He’s also told me he wants to try out for football next year', 'predicate': [{'str': 'wants', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'to try out for football next year', 'type': 'declarative'}
# {'sentence': 'I don’t think I’m ready for the pain that’s going to go along with the teenage years', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I’m ready for the pain that’s going to go along with the teenage years', 'type': 'declarative'}
# {'sentence': 'I don’t think I’m ready for the pain that’s going to go along with the teenage years', 'predicate': [{'str': 'going', 'lemma': 'go', 'POS': 'VERB'}], 'clause': 'to go along with the teenage years', 'type': 'declarative'}
# {'sentence': "To any studio execs who may be reading this: I can't guarantee that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers.", 'predicate': [{'str': 'reading', 'lemma': 'read', 'POS': 'VERB'}], 'clause': "this: I can't guarantee that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers", 'type': 'declarative'}
# {'sentence': "To any studio execs who may be reading this: I can't guarantee that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers.", 'predicate': [{'str': 'guarantee', 'lemma': 'guarantee', 'POS': 'VERB'}], 'clause': 'that following my advice will help your format win the war, but doing so will certainly improve your products, and should make High-Def discs more appealing to your target customers', 'type': 'declarative'}
# {'sentence': 'I realize this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'predicate': [{'str': 'realize', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'type': 'declarative'}
# {'sentence': 'I realize this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'predicate': [{'str': 'getting', 'lemma': 'get', 'POS': 'VERB'}], 'clause': 'straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'type': 'declarative'}
# {'sentence': 'I realize this may sound like a contradiction to my last point about getting straight to the movie, but the fact of the matter is that High-Def discs usually have a number of audio, subtitle, and other setup choices to dig through before you can finally sit down to watch the movie', 'predicate': [{'str': 'dig', 'lemma': 'dig', 'POS': 'VERB'}, {'str': 'through', 'lemma': 'through', 'POS': 'ADP'}], 'clause': 'before you can finally sit down to watch the movie', 'type': 'declarative'}
# {'sentence': "Just to reiterate that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'predicate': [{'str': 'reiterate', 'lemma': 'reiterate', 'POS': 'VERB'}], 'clause': "that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'type': 'declarative'}
# {'sentence': "Just to reiterate that while I appreciate, and even enjoy, contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'predicate': [{'str': 'enjoy', 'lemma': 'enjoy', 'POS': 'VERB'}], 'clause': ", contact from readers, I'm absolutely not interested in whatever spammy commercial venture you're proposing", 'type': 'declarative'}
# {'sentence': 'And that Jamie Schler article…I wish I were as fiery', 'predicate': [{'str': 'wish', 'lemma': 'wish', 'POS': 'VERB'}], 'clause': 'I were as fiery', 'type': 'declarative'}
# {'sentence': 'I think not letting one’s computer get in the way of real life is sound advice', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'not letting one’s computer get in the way of real life is sound advice', 'type': 'declarative'}
# {'sentence': 'I think not letting one’s computer get in the way of real life is sound advice', 'predicate': [{'str': 'get', 'lemma': 'get', 'POS': 'VERB'}, {'str': 'in', 'lemma': 'in', 'POS': 'ADP'}], 'clause': 'the way of real life is sound advice', 'type': 'declarative'}
# {'sentence': 'Later in the article, Portnoy says that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things.', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that for all the freedom the site allots its various personalities, the one topic Barstool bloggers and readers are both actively uninterested in is politics, a topic that’s infiltrated the sports world to an unprecedented degree in recent years due to the National Anthem protests, among other things', 'type': 'declarative'}
# {'sentence': 'No matter how ridiculous the jokes, or over the top the take, it was understood by most that we are just here to make people laugh.', 'predicate': [{'str': 'understood', 'lemma': 'understand', 'POS': 'VERB'}, {'str': 'by', 'lemma': 'by', 'POS': 'ADP'}], 'clause': 'most that we are just here to make people laugh', 'type': 'declarative'}
# {'sentence': 'No matter how ridiculous the jokes, or over the top the take, it was understood by most that we are just here to make people laugh.', 'predicate': [{'str': 'make', 'lemma': 'make', 'POS': 'VERB'}], 'clause': 'people laugh', 'type': 'declarative'}
# {'sentence': 'On that count, he knows all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on.', 'predicate': [{'str': 'knows', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on', 'type': 'declarative'}
# {'sentence': 'On that count, he knows all too well that a combative, anti-PC, anti-moral grandstanding ethos is morphing into a political ideology unto itself—one that Barstool is both defining and capitalizing on.', 'predicate': [{'str': 'defining', 'lemma': 'define', 'POS': 'VERB'}], 'clause': 'and capitalizing on', 'type': 'declarative'}
# {'sentence': 'and I guess they smelt well.', 'predicate': [{'str': 'guess', 'lemma': 'guess', 'POS': 'VERB'}], 'clause': 'they smelt well', 'type': 'declarative'}
# {'sentence': 'Michelle Obama says her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'type': 'declarative'}
# {'sentence': 'Michelle Obama says her family has decided to make a Portuguese Water Dog the first dog around the Obama White House', 'predicate': [{'str': 'decided', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'to make a Portuguese Water Dog the first dog around the Obama White House', 'type': 'declarative'}
# {'sentence': 'The First Lady told People Magazine the Obamas are searching animal rescues for that particular breed.', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'People Magazine the Obamas are searching animal rescues for that particular breed', 'type': 'declarative'}
# {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}
# {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': [{'str': 'hopes', 'lemma': 'hope', 'POS': 'VERB'}], 'clause': 'the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}
# {'sentence': 'Obama says she hopes the lucky Portuguese Water Dog will move into the White House in April after she and President Obama take their daughters on Spring Break.', 'predicate': [{'str': 'move', 'lemma': 'move', 'POS': 'VERB'}, {'str': 'into', 'lemma': 'into', 'POS': 'ADP'}], 'clause': 'the White House in April after she and President Obama take their daughters on Spring Break', 'type': 'declarative'}
# {'sentence': 'Obama says she learned from Sen', 'predicate': [{'str': 'says', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'she learned from Sen', 'type': 'declarative'}
# {'sentence': "I know that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': "that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'type': 'declarative'}
# {'sentence': "I know that Apple does provide a converter that turns the charging port into a headphone jack, but this means you have to do a lot of plugging and unplugging every time you want to listen to music - and since my strength is limited, that's difficult for me", 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': "to listen to music - and since my strength is limited, that's difficult for me", 'type': 'declarative'}
# {'sentence': 'Is it accurate to say that you are a specialist in a particular field?', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that you are a specialist in a particular field', 'type': 'declarative'}
# {'sentence': 'From movement, form, cooking, to DIY, and expulsion administrations, on the off chance that you realize how to accomplish something especially well, why not tell the world through a blog or video blog?', 'predicate': [{'str': 'realize', 'lemma': 'realize', 'POS': 'VERB'}], 'clause': 'how to accomplish something especially well, why not tell the world through a blog or video blog', 'type': 'constituent'}
# {'sentence': 'I know you have made a planned to leave your 9-to-5 job', 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'you have made a planned to leave your 9-to-5 job', 'type': 'declarative'}
# {'sentence': 'I know you have made a planned to leave your 9-to-5 job', 'predicate': [{'str': 'planned', 'lemma': 'plan', 'POS': 'VERB'}], 'clause': 'to leave your 9-to-5 job', 'type': 'declarative'}
# {'sentence': 'Plus, I don’t think I barely snacked at all', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'I barely snacked at all', 'type': 'declarative'}
# {'sentence': 'I too have been upping the healthy fats in my diet an have definitely noticed that I can last for up to 6 hours without feeling hunger pains!!', 'predicate': [{'str': 'noticed', 'lemma': 'notice', 'POS': 'VERB'}], 'clause': 'that I can last for up to 6 hours without feeling hunger pains!', 'type': 'declarative'}
# {'sentence': 'Some people say that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive tract', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that you shouldn’t eat a lot of fats when you eat a raw diet, as it is hard on the digestive tract', 'type': 'declarative'}
# {'sentence': 'Do you think the 01753476428 was a harass phone number?', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'the 01753476428 was a harass phone number', 'type': 'declarative'}
# {'sentence': 'NationalLedger.com reports that Christina Aguilera risked re-igniting her feud with Britney Spears by a comment made on her wedding day', 'predicate': [{'str': 'reports', 'lemma': 'report', 'POS': 'VERB'}], 'clause': 'that Christina Aguilera risked re-igniting her feud with Britney Spears by a comment made on her wedding day', 'type': 'declarative'}
# {'sentence': 'Christina’s rep denies she made any comment however.', 'predicate': [{'str': 'denies', 'lemma': 'deny', 'POS': 'VERB'}], 'clause': 'she made any comment however', 'type': 'declarative'}
# {'sentence': 'In this sense, Mignolo argues that while modernity is not strictly a European phenomenon, its rhetoric -as Dussel argues- is formed by European philosophers, academics and politicians', 'predicate': [{'str': 'argues', 'lemma': 'argue', 'POS': 'VERB'}], 'clause': 'that while modernity is not strictly a European phenomenon, its rhetoric -as Dussel argues- is formed by European philosophers, academics and politicians', 'type': 'declarative'}
# {'sentence': "Business guests appreciate that our downtown hotel's location in Lexington, KY is close to IBM, PNC Bank, Fifth Third Bank, Ashland and UPS", 'predicate': [{'str': 'appreciate', 'lemma': 'appreciate', 'POS': 'VERB'}], 'clause': "that our downtown hotel's location in Lexington, KY is close to IBM, PNC Bank, Fifth Third Bank, Ashland and UPS", 'type': 'declarative'}
# {'sentence': 'AEPi is proud to say that we are one of the loudest Jewish voices on campus', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that we are one of the loudest Jewish voices on campus', 'type': 'declarative'}
# {'sentence': 'On January 31, 2015, The Sacramento Bee reported that the AEPi building in Davis had been tagged with two large swastikas', 'predicate': [{'str': 'reported', 'lemma': 'report', 'POS': 'VERB'}], 'clause': 'that the AEPi building in Davis had been tagged with two large swastikas', 'type': 'declarative'}
# {'sentence': 'I think this is just too cool for school!!!!!', 'predicate': [{'str': 'think', 'lemma': 'think', 'POS': 'VERB'}], 'clause': 'this is just too cool for school!!!!', 'type': 'declarative'}
# {'sentence': 'I checked in with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'predicate': [{'str': 'checked', 'lemma': 'check', 'POS': 'VERB'}, {'str': 'in', 'lemma': 'in', 'POS': 'ADP'}], 'clause': 'with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'type': 'constituent'}
# {'sentence': 'I checked in with the in 2 days (when the repair should have been complete) and was told it would be one more day - they were doing some final tests', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'it would be one more day - they were doing some final tests', 'type': 'declarative'}
# {'sentence': 'The next day I learned that they had not put any real time evaluating my laptop and would require a couple more days', 'predicate': [{'str': 'learned', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'that they had not put any real time evaluating my laptop and would require a couple more days', 'type': 'declarative'}
# {'sentence': 'The next day I learned that they had not put any real time evaluating my laptop and would require a couple more days', 'predicate': [{'str': 'evaluating', 'lemma': 'evaluate', 'POS': 'VERB'}], 'clause': 'my laptop and would require a couple more days', 'type': 'declarative'}
# {'sentence': 'After two more days they said they needed to repair the backlight before trying to determine the other problem', 'predicate': [{'str': 'trying', 'lemma': 'try', 'POS': 'VERB'}], 'clause': 'to determine the other problem', 'type': 'declarative'}
# {'sentence': '\u200bDigging a little deeper, we managed to find out that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues.', 'predicate': [{'str': 'managed', 'lemma': 'manage', 'POS': 'VERB'}], 'clause': 'to find out that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues', 'type': 'declarative'}
# {'sentence': '\u200bDigging a little deeper, we managed to find out that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues.', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}, {'str': 'out', 'lemma': 'out', 'POS': 'ADP'}], 'clause': 'that Carole Baskin, CEO of Big Cat Rescue, and Wayne Pacelle, CEO of the HSUS, are former colleagues', 'type': 'declarative'}
# {'sentence': "It's interesting to know that Wayne was a co-founder of the Humane Society Legislative Fund", 'predicate': [{'str': 'know', 'lemma': 'know', 'POS': 'VERB'}], 'clause': 'that Wayne was a co-founder of the Humane Society Legislative Fund', 'type': 'declarative'}
# {'sentence': "At Radon Fan Guys, we understand that you have to stay within your price range and save cash everywhere you're able to", 'predicate': [{'str': 'understand', 'lemma': 'understand', 'POS': 'VERB'}], 'clause': "that you have to stay within your price range and save cash everywhere you're able to", 'type': 'declarative'}
# {'sentence': 'We use the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'predicate': [{'str': 'use', 'lemma': 'use', 'POS': 'VERB'}], 'clause': 'the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'type': 'declarative'}
# {'sentence': 'We use the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'predicate': [{'str': 'ensure', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'type': 'declarative'}
# {'sentence': 'We use the finest materials and techniques to ensure that your task is going to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'predicate': [{'str': 'going', 'lemma': 'go', 'POS': 'VERB'}], 'clause': 'to tolerate the years, and cost less money with techniques which do not affect the excellence of any project', 'type': 'constituent'}
# {'sentence': 'Then he shocked her by declaring that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'predicate': [{'str': 'shocked', 'lemma': 'shock', 'POS': 'VERB'}], 'clause': 'her by declaring that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'type': 'declarative'}
# {'sentence': 'Then he shocked her by declaring that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'predicate': [{'str': 'declaring', 'lemma': 'declare', 'POS': 'VERB'}], 'clause': 'that he was offering “living water” greater than Jacob’s well, greater than either the Temple or the holy places of Samaria', 'type': 'declarative'}
# {'sentence': 'The Founders Scholarship was created in 2010 by fifteen individuals or couples to ensure that all graduating Mackinac Island students have an opportunity for a multi-year scholarship award', 'predicate': [{'str': 'ensure', 'lemma': 'ensure', 'POS': 'VERB'}], 'clause': 'that all graduating Mackinac Island students have an opportunity for a multi-year scholarship award', 'type': 'declarative'}
# {'sentence': 'The Local Government Association estimates that by 2025, the funding gap will grow to £3bn for children’s social care alone.', 'predicate': [{'str': 'estimates', 'lemma': 'estimate', 'POS': 'VERB'}], 'clause': 'that by 2025, the funding gap will grow to £3bn for children’s social care alone', 'type': 'declarative'}
# {'sentence': 'We are told that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection services', 'predicate': [{'str': 'told', 'lemma': 'tell', 'POS': 'VERB'}], 'clause': 'that ministers are minded to appoint a commissioner shortly to intervene in the council’s operations to stabilise and improve child protection services', 'type': 'declarative'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'quoted', 'lemma': 'quote', 'POS': 'VERB'}, {'str': 'as', 'lemma': 'as', 'POS': 'ADP'}], 'clause': 'saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'type': 'declarative'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'saying', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'type': 'declarative'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'propose', 'lemma': 'propose', 'POS': 'VERB'}], 'clause': 'cuts, but it is difficult to see how this could be the case', 'type': 'constituent'}
# {'sentence': 'Northampton’s leader, Matt Golby, has been quoted as saying that no children will be put in danger as a result of propose cuts, but it is difficult to see how this could be the case', 'predicate': [{'str': 'see', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'how this could be the case', 'type': 'constituent'}
# {'sentence': 'But the government is already backing down on this claim, with Jo Farrar, director general to the Ministry of Housing, Communities and Local Government, telling the public accounts committee this week that they do not expect these funds to buy additional capacity', 'predicate': [{'str': 'backing', 'lemma': 'back', 'POS': 'VERB'}, {'str': 'down', 'lemma': 'down', 'POS': 'ADP'}], 'clause': 'on this claim, with Jo Farrar, director general to the Ministry of Housing, Communities and Local Government, telling the public accounts committee this week that they do not expect these funds to buy additional capacity', 'type': 'declarative'}
# ...
# {'sentence': 'So whether or not we have to be singing in order to hear this, or whether it is just going to manifest, I really do not know, but glory to God.', 'predicate': [{'str': 'going', 'lemma': 'go', 'POS': 'VERB'}], 'clause': 'to manifest, I really do not know, but glory to God', 'type': 'declarative'}
# {'sentence': 'The authors did not identify whether the subjects were stretching completely cold, or whether they had \x93warmed up\x94 in any way prior to the stretching episode, which is common practice.', 'predicate': [{'str': 'identify', 'lemma': 'identify', 'POS': 'VERB'}], 'clause': 'whether the subjects were stretching completely cold, or whether they had \x93warmed up\x94 in any way prior to the stretching episode, which is common practice', 'type': 'alternative'}
# {'sentence': 'After spending some time debating over whether to remain true to their artistic vision or try to be more commercial, they decided it would be better to "go down in flames" than compromise their musical integrity.', 'predicate': [{'str': 'debating', 'lemma': 'debate', 'POS': 'VERB'}, {'str': 'over', 'lemma': 'over', 'POS': 'ADP'}], 'clause': 'whether to remain true to their artistic vision or try to be more commercial, they decided it would be better to "go down in flames" than compromise their musical integrity', 'type': 'alternative'}
# {'sentence': 'After spending some time debating over whether to remain true to their artistic vision or try to be more commercial, they decided it would be better to "go down in flames" than compromise their musical integrity.', 'predicate': [{'str': 'go', 'lemma': 'go', 'POS': 'VERB'}], 'clause': 'down in flames" than compromise their musical integrity', 'type': 'declarative'}
# {'sentence': 'An officer has to decide whether to serve India after gaining experience or stay back.', 'predicate': [{'str': 'decide', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether to serve India after gaining experience or stay back', 'type': 'alternative'}
# {'sentence': 'In the end, it\x92s almost hard to say whether Days of Future Past is a step forward \x96 or backward \x96 for the X-Men.', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'whether Days of Future Past is a step forward \x96 or backward \x96 for the X-Men', 'type': 'alternative'}
# {'sentence': 'Somehow he found himself back in his body - he can\x92t recall whether the water pushed him out or if somebody pulled him to safety \x96 but he was never again the same person.', 'predicate': [{'str': 'found', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'himself back in his body - he can\x92t recall whether the water pushed him out or if somebody pulled him to safety \x96 but he was never again the same person', 'type': 'alternative'}
# {'sentence': 'Somehow he found himself back in his body - he can\x92t recall whether the water pushed him out or if somebody pulled him to safety \x96 but he was never again the same person.', 'predicate': [{'str': 'recall', 'lemma': 'recall', 'POS': 'VERB'}], 'clause': 'whether the water pushed him out or if somebody pulled him to safety \x96 but he was never again the same person', 'type': 'alternative'}
# {'sentence': 'There are various types of creams and these are distinguished by their fat content and or whether they have been whipped or heat treated.', 'predicate': [{'str': 'are', 'lemma': 'be', 'POS': 'VERB'}], 'clause': 'various types of creams and these are distinguished by their fat content and or whether they have been whipped or heat treated', 'type': 'alternative'}
# {'sentence': 'LONDON (AP) \x97 British Prime Minister Theresa May is hunkered down with close allies as she considers whether to give in to relentless pressure to resign, or fight on to save her Brexit plan and her premiership.', 'predicate': [{'str': 'considers', 'lemma': 'consider', 'POS': 'VERB'}], 'clause': 'whether to give in to relentless pressure to resign, or fight on to save her Brexit plan and her premiership', 'type': 'alternative'}
# {'sentence': 'LONDON (AP) \x97 British Prime Minister Theresa May is hunkered down with close allies as she considers whether to give in to relentless pressure to resign, or fight on to save her Brexit plan and her premiership.', 'predicate': [{'str': 'fight', 'lemma': 'fight', 'POS': 'VERB'}, {'str': 'on', 'lemma': 'on', 'POS': 'ADP'}], 'clause': 'to save her Brexit plan and her premiership', 'type': 'declarative'}
# {'sentence': 'You should check whether the doors are made of solid wood or metal.', 'predicate': [{'str': 'check', 'lemma': 'check', 'POS': 'VERB'}], 'clause': 'whether the doors are made of solid wood or metal', 'type': 'alternative'}
# {'sentence': 'I almost asked whether she\x92d been stabbed in a literal or metaphorical Barcelona, but it sounded snide so I didn\x92t say anything.', 'predicate': [{'str': 'asked', 'lemma': 'ask', 'POS': 'VERB'}], 'clause': 'whether she\x92d been stabbed in a literal or metaphorical Barcelona, but it sounded snide so I didn\x92t say anything', 'type': 'alternative'}
# {'sentence': 'The other two cats stood poised nearby, as if undecided on whether to back up their fellow or choose the better part of valor.', 'predicate': [{'str': 'stood', 'lemma': 'stand', 'POS': 'VERB'}], 'clause': 'poised nearby, as if undecided on whether to back up their fellow or choose the better part of valor', 'type': 'alternative'}
# {'sentence': 'The other two cats stood poised nearby, as if undecided on whether to back up their fellow or choose the better part of valor.', 'predicate': [{'str': 'back', 'lemma': 'back', 'POS': 'VERB'}, {'str': 'up', 'lemma': 'up', 'POS': 'ADP'}], 'clause': 'their fellow or choose the better part of valor', 'type': 'declarative'}
# {'sentence': 'CFIUS would have 30 days to decide whether to require a full formal filing or determine that no further action is necessary.', 'predicate': [{'str': 'decide', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether to require a full formal filing or determine that no further action is necessary', 'type': 'alternative'}
# {'sentence': 'CFIUS would have 30 days to decide whether to require a full formal filing or determine that no further action is necessary.', 'predicate': [{'str': 'require', 'lemma': 'require', 'POS': 'VERB'}], 'clause': 'a full formal filing or determine that no further action is necessary', 'type': 'declarative'}
# {'sentence': 'CFIUS would have 30 days to decide whether to require a full formal filing or determine that no further action is necessary.', 'predicate': [{'str': 'determine', 'lemma': 'determine', 'POS': 'VERB'}], 'clause': 'that no further action is necessary', 'type': 'declarative'}
# {'sentence': 'It is difficult to predict whether the Supreme Court\x92s grant of certiorari in Bilski signals an intent to significantly narrow or expand the scope of patent eligibility under 35 U.S.C.', 'predicate': [{'str': 'predict', 'lemma': 'predict', 'POS': 'VERB'}], 'clause': 'whether the Supreme Court\x92s grant of certiorari in Bilski signals an intent to significantly narrow or expand the scope of patent eligibility under 35 U.S.C.', 'type': 'alternative'}
# {'sentence': 'Additional studies are needed to clarify whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein.', 'predicate': [{'str': 'needed', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to clarify whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein', 'type': 'alternative'}
# {'sentence': 'Additional studies are needed to clarify whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein.', 'predicate': [{'str': 'clarify', 'lemma': 'clarify', 'POS': 'VERB'}], 'clause': 'whether this effect is consequent to a structural modification of PrPC, or a dislodgment from natural interacting partners, or a modification of the membrane lipid architecture surrounding the protein', 'type': 'alternative'}
# {'sentence': 'Deciding whether you should join a team or go at it alone will have a significant impact on your success.', 'predicate': [{'str': 'Deciding', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether you should join a team or go at it alone will have a significant impact on your success', 'type': 'alternative'}
# {'sentence': 'Deciding whether you should join a team or go at it alone will have a significant impact on your success.', 'predicate': [{'str': 'go', 'lemma': 'go', 'POS': 'VERB'}, {'str': 'at', 'lemma': 'at', 'POS': 'ADP'}], 'clause': 'it alone will have a significant impact on your success', 'type': 'declarative'}
# {'sentence': 'Sources do not say whether he worked for a shipping company or for a government agency, such as the Federal Maritime Commission or the New York Port Authority.', 'predicate': [{'str': 'say', 'lemma': 'say', 'POS': 'VERB'}], 'clause': 'whether he worked for a shipping company or for a government agency, such as the Federal Maritime Commission or the New York Port Authority', 'type': 'alternative'}
# {'sentence': 'To find out whether Intertops is as strong as ever, or is beginning to show its age, check out the rest of our review.', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}, {'str': 'out', 'lemma': 'out', 'POS': 'ADP'}], 'clause': 'whether Intertops is as strong as ever, or is beginning to show its age, check out the rest of our review', 'type': 'alternative'}
# {'sentence': 'To find out whether Intertops is as strong as ever, or is beginning to show its age, check out the rest of our review.', 'predicate': [{'str': 'show', 'lemma': 'show', 'POS': 'VERB'}], 'clause': 'its age, check out the rest of our review', 'type': 'declarative'}
# {'sentence': 'The scope of processing personal data primarily depends on whether a user simply visits one of our websites, uses them as a registered user or is just registering.', 'predicate': [{'str': 'uses', 'lemma': 'use', 'POS': 'VERB'}], 'clause': 'them as a registered user or is just registering', 'type': 'declarative'}
# {'sentence': 'The scope of processing personal data primarily depends on whether a user simply visits one of our websites, uses them as a registered user or is just registering.', 'predicate': [{'str': 'registered', 'lemma': 'register', 'POS': 'VERB'}], 'clause': 'user or is just registering', 'type': 'declarative'}
# {'sentence': 'reCAPTCHA is designed to check whether data is entered on our websites by a human or by automated software, e.g.', 'predicate': [{'str': 'designed', 'lemma': 'design', 'POS': 'VERB'}], 'clause': 'to check whether data is entered on our websites by a human or by automated software, e.g.', 'type': 'alternative'}
# {'sentence': 'reCAPTCHA is designed to check whether data is entered on our websites by a human or by automated software, e.g.', 'predicate': [{'str': 'check', 'lemma': 'check', 'POS': 'VERB'}], 'clause': 'whether data is entered on our websites by a human or by automated software, e.g.', 'type': 'alternative'}
# {'sentence': 'So I called Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it.', 'predicate': [{'str': 'called', 'lemma': 'call', 'POS': 'VERB'}], 'clause': 'Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it', 'type': 'constituent'}
# {'sentence': 'So I called Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it.', 'predicate': [{'str': 'asked', 'lemma': 'ask', 'POS': 'VERB'}], 'clause': 'him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it', 'type': 'alternative'}
# {'sentence': 'So I called Steve Koepp, my old editor, who now supervises TIME books, and asked him whether, after nine years, TIME had run out of ways to exploit the TIME 100 or I had run out of ways to make fun of it.', 'predicate': [{'str': 'exploit', 'lemma': 'exploit', 'POS': 'VERB'}], 'clause': 'the TIME 100 or I had run out of ways to make fun of it', 'type': 'declarative'}
# {'sentence': 'We just have to guess whether the card on the card on the player or the banker who will be the winner, or the game ends in a tie.', 'predicate': [{'str': 'guess', 'lemma': 'guess', 'POS': 'VERB'}], 'clause': 'whether the card on the card on the player or the banker who will be the winner, or the game ends in a tie', 'type': 'alternative'}
# {'sentence': 'For centuries Jewish villages had to decide whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry.', 'predicate': [{'str': 'decide', 'lemma': 'decide', 'POS': 'VERB'}], 'clause': 'whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry', 'type': 'alternative'}
# {'sentence': 'For centuries Jewish villages had to decide whether to stay and hope to survive hard times, or whether to flee across rivers and borders with what they could carry.', 'predicate': [{'str': 'hope', 'lemma': 'hope', 'POS': 'VERB'}], 'clause': 'to survive hard times, or whether to flee across rivers and borders with what they could carry', 'type': 'alternative'}
# {'sentence': 'You can\x92t easily configure whether you want the video to be oriented horizontally (landscape) or vertically (portrait).', 'predicate': [{'str': 'configure', 'lemma': 'configure', 'POS': 'VERB'}], 'clause': 'whether you want the video to be oriented horizontally (landscape) or vertically (portrait)', 'type': 'alternative'}
# {'sentence': 'You can\x92t easily configure whether you want the video to be oriented horizontally (landscape) or vertically (portrait).', 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'the video to be oriented horizontally (landscape) or vertically (portrait)', 'type': 'declarative'}
# {'sentence': 'This includes the rights to property, the ability to raise children, and whether you will pay or receive alimony.', 'predicate': [{'str': 'includes', 'lemma': 'include', 'POS': 'VERB'}], 'clause': 'the rights to property, the ability to raise children, and whether you will pay or receive alimony', 'type': 'alternative'}
# {'sentence': 'This includes the rights to property, the ability to raise children, and whether you will pay or receive alimony.', 'predicate': [{'str': 'raise', 'lemma': 'raise', 'POS': 'VERB'}], 'clause': 'children, and whether you will pay or receive alimony', 'type': 'alternative'}
# {'sentence': "I've gone back and forth on whether Desire or BOTT is my favorite Dylan record (with Blonde on Blonde working it's way in there from time to time).", 'predicate': [{'str': 'gone', 'lemma': 'go', 'POS': 'VERB'}], 'clause': "back and forth on whether Desire or BOTT is my favorite Dylan record (with Blonde on Blonde working it's way in there from time to time)", 'type': 'alternative'}
# {'sentence': 'What difference does it make whether Jesus or the Holy Spirit lives in my heart?\x94.', 'predicate': [{'str': 'make', 'lemma': 'make', 'POS': 'VERB'}], 'clause': 'whether Jesus or the Holy Spirit lives in my heart?\x94.', 'type': 'alternative'}

# %%
#running baseline on adversarial set
baseline_advers = []
for s in advers_sentences:
  my_sent = nlp(s)
  outs = get_baseline(my_sent, print_negs = False)
  baseline_advers += outs
# Out:
# {'sentence': 'Shower Doors is a relatively small company that can offer you more personalized service, which is something not offered by many companies today.', 'predicate': [{'str': 'offer', 'lemma': 'offer', 'POS': 'VERB'}], 'clause': 'you more personalized service, which is something not offered by many companies today', 'type': 'constituent'}
# {'sentence': 'Hardware is very well made, offering a diverse selection of style and color', 'predicate': [{'str': 'made', 'lemma': 'make', 'POS': 'VERB'}], 'clause': ', offering a diverse selection of style and color', 'type': 'declarative'}
# {'sentence': 'Now that you know your priorities and price range, use the criteria to narrow your home search', 'predicate': [{'str': 'use', 'lemma': 'use', 'POS': 'VERB'}], 'clause': 'the criteria to narrow your home search', 'type': 'declarative'}
# {'sentence': 'Start with my Featured Listings to see examples of beautiful North Shore homes', 'predicate': [{'str': 'Start', 'lemma': 'start', 'POS': 'VERB'}, {'str': 'with', 'lemma': 'with', 'POS': 'ADP'}], 'clause': 'my Featured Listings to see examples of beautiful North Shore homes', 'type': 'declarative'}
# {'sentence': 'Contact me to arrange a personal showing of any home in the North Shore area!', 'predicate': [{'str': 'Contact', 'lemma': 'contact', 'POS': 'VERB'}], 'clause': 'me to arrange a personal showing of any home in the North Shore area', 'type': 'declarative'}
# {'sentence': 'We took to the only wildflower field that I could find this year, which was in Huntsville', 'predicate': [{'str': 'took', 'lemma': 'take', 'POS': 'VERB'}, {'str': 'to', 'lemma': 'to', 'POS': 'ADP'}], 'clause': 'the only wildflower field that I could find this year, which was in Huntsville', 'type': 'constituent'}
# {'sentence': 'We took to the only wildflower field that I could find this year, which was in Huntsville', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'this year, which was in Huntsville', 'type': 'constituent'}
# {'sentence': 'I love the rich colors it has to offer and the beautiful family that I was able to photograph', 'predicate': [{'str': 'love', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'the rich colors it has to offer and the beautiful family that I was able to photograph', 'type': 'declarative'}
# {'sentence': 'I love the rich colors it has to offer and the beautiful family that I was able to photograph', 'predicate': [{'str': 'offer', 'lemma': 'offer', 'POS': 'VERB'}], 'clause': 'and the beautiful family that I was able to photograph', 'type': 'declarative'}
# {'sentence': 'If you’d like to learn more about my sessions, click here', 'predicate': [{'str': 'learn', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'more about my sessions, click here', 'type': 'declarative'}
# {'sentence': 'And to get in touch, ask questions, or just say hi.', 'predicate': [{'str': 'ask', 'lemma': 'ask', 'POS': 'VERB'}], 'clause': 'questions, or just say hi', 'type': 'declarative'}
# {'sentence': 'I’d love to hear from you.', 'predicate': [{'str': 'love', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'to hear from you', 'type': 'declarative'}
# {'sentence': 'If your husband doesn’t love suspenders and has never worn them a day in his life, please leave those at the store', 'predicate': [{'str': 'love', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'suspenders and has never worn them a day in his life, please leave those at the store', 'type': 'declarative'}
# {'sentence': 'If you love white and jeans, find different styles of white shirts and different tones of blue jeans (dark, weathered, light, etc)', 'predicate': [{'str': 'love', 'lemma': 'love', 'POS': 'VERB'}], 'clause': 'white and jeans, find different styles of white shirts and different tones of blue jeans (dark, weathered, light, etc', 'type': 'declarative'}
# {'sentence': 'And if you do not want to purchase clothing, I do have a few clothing options if you’d like to come to the studio to take a look.', 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'to purchase clothing, I do have a few clothing options if you’d like to come to the studio to take a look', 'type': 'declarative'}
# {'sentence': 'And if you do not want to purchase clothing, I do have a few clothing options if you’d like to come to the studio to take a look.', 'predicate': [{'str': 'come', 'lemma': 'come', 'POS': 'VERB'}, {'str': 'to', 'lemma': 'to', 'POS': 'ADP'}], 'clause': 'the studio to take a look', 'type': 'declarative'}
# {'sentence': 'My goal is to document your life the way your kids sees it, and the way you want to be remembered.', 'predicate': [{'str': 'document', 'lemma': 'document', 'POS': 'VERB'}], 'clause': 'your life the way your kids sees it, and the way you want to be remembered', 'type': 'declarative'}
# {'sentence': 'My goal is to document your life the way your kids sees it, and the way you want to be remembered.', 'predicate': [{'str': 'sees', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'it, and the way you want to be remembered', 'type': 'declarative'}
# {'sentence': 'My goal is to document your life the way your kids sees it, and the way you want to be remembered.', 'predicate': [{'str': 'want', 'lemma': 'want', 'POS': 'VERB'}], 'clause': 'to be remembered', 'type': 'declarative'}
# {'sentence': 'We took to a location I had my eyes on for about a year', 'predicate': [{'str': 'took', 'lemma': 'take', 'POS': 'VERB'}, {'str': 'to', 'lemma': 'to', 'POS': 'ADP'}], 'clause': 'a location I had my eyes on for about a year', 'type': 'declarative'}
# {'sentence': 'Aubrie was a sleep fighter of champs but we managed to get a few minutes of her sleeping on her belly towards the end of her The Woodlands Newborn Studio session', 'predicate': [{'str': 'get', 'lemma': 'get', 'POS': 'VERB'}], 'clause': 'a few minutes of her sleeping on her belly towards the end of her The Woodlands Newborn Studio session', 'type': 'declarative'}
# {'sentence': 'In each of these collisions as reported by the MSHP a vehicle crossed the center line and struck another vehicle head-on or in several instances, a driver was driving the wrong way on a highway and then struck another vehicle head-on', 'predicate': [{'str': 'reported', 'lemma': 'report', 'POS': 'VERB'}, {'str': 'by', 'lemma': 'by', 'POS': 'ADP'}], 'clause': 'the MSHP a vehicle crossed the center line and struck another vehicle head-on or in several instances, a driver was driving the wrong way on a highway and then struck another vehicle head-on', 'type': 'declarative'}
# {'sentence': 'I could find this other answer which can help you to disable the blogposts.', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'this other answer which can help you to disable the blogposts', 'type': 'constituent'}
# {'sentence': 'I could find this other answer which can help you to disable the blogposts.', 'predicate': [{'str': 'help', 'lemma': 'help', 'POS': 'VERB'}], 'clause': 'you to disable the blogposts', 'type': 'declarative'}
# {'sentence': 'If you need something to brighten your day, then Tiny Tim’s channel is for you', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'something to brighten your day, then Tiny Tim’s channel is for you', 'type': 'declarative'}
# {'sentence': 'The concept is simple; Tiny Tim’s videos are a series of prank calls in which he puts on a child’s voice and pretends to be a kid navigating his way through adult life', 'predicate': [{'str': 'calls', 'lemma': 'call', 'POS': 'VERB'}, {'str': 'in', 'lemma': 'in', 'POS': 'ADP'}], 'clause': 'which he puts on a child’s voice and pretends to be a kid navigating his way through adult life', 'type': 'constituent'}
# {'sentence': 'The concept is simple; Tiny Tim’s videos are a series of prank calls in which he puts on a child’s voice and pretends to be a kid navigating his way through adult life', 'predicate': [{'str': 'pretends', 'lemma': 'pretend', 'POS': 'VERB'}], 'clause': 'to be a kid navigating his way through adult life', 'type': 'declarative'}
# {'sentence': 'From trying to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult.', 'predicate': [{'str': 'trying', 'lemma': 'try', 'POS': 'VERB'}], 'clause': 'to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult', 'type': 'constituent'}
# {'sentence': 'From trying to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult.', 'predicate': [{'str': 'buying', 'lemma': 'buy', 'POS': 'VERB'}], 'clause': 'a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult', 'type': 'constituent'}
# {'sentence': 'From trying to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult.', 'predicate': [{'str': 'witnessed', 'lemma': 'witness', 'POS': 'VERB'}], 'clause': 'a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult', 'type': 'constituent'}
# {'sentence': 'From trying to book a tattoo to buying a house, we’ve witnessed a number of hilarious pranks in which Tiny Tim tries to unsuccessfully be an adult.', 'predicate': [{'str': 'tries', 'lemma': 'try', 'POS': 'VERB'}], 'clause': 'to unsuccessfully be an adult', 'type': 'declarative'}
# {'sentence': 'You’re not really going to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'predicate': [{'str': 'going', 'lemma': 'go', 'POS': 'VERB'}], 'clause': 'to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'type': 'constituent'}
# {'sentence': 'You’re not really going to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'type': 'constituent'}
# {'sentence': 'You’re not really going to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'predicate': [{'str': 'find', 'lemma': 'find', 'POS': 'VERB'}], 'clause': 'hysterically funny material which is guaranteed to put a smile on your face', 'type': 'constituent'}
# {'sentence': 'You’re not really going to find any profound content here but you will find hysterically funny material which is guaranteed to put a smile on your face', 'predicate': [{'str': 'guaranteed', 'lemma': 'guarantee', 'POS': 'VERB'}], 'clause': 'to put a smile on your face', 'type': 'declarative'}
# {'sentence': 'It’s impossible to watch any of Tim’s videos without belly laughing', 'predicate': [{'str': 'watch', 'lemma': 'watch', 'POS': 'VERB'}], 'clause': 'any of Tim’s videos without belly laughing', 'type': 'declarative'}
# {'sentence': 'He phones a jewellers to get advice on the best engagement ring to buy.', 'predicate': [{'str': 'get', 'lemma': 'get', 'POS': 'VERB'}], 'clause': 'advice on the best engagement ring to buy', 'type': 'declarative'}
# {'sentence': "I don't need any building process on NodeJS right now, but I should do this in your case.", 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'any building process on NodeJS right now, but I should do this in your case', 'type': 'declarative'}
# {'sentence': "For me there's no build step - ie, components are loaded straight in the browser.", 'predicate': [{'str': "'s", 'lemma': 'be', 'POS': 'VERB'}], 'clause': 'no build step - ie, components are loaded straight in the browser', 'type': 'declarative'}
# {'sentence': 'Suggesting tool-specific procedures and folder structures would be against its intended design.', 'predicate': [{'str': 'Suggesting', 'lemma': 'suggest', 'POS': 'VERB'}], 'clause': 'tool-specific procedures and folder structures would be against its intended design', 'type': 'declarative'}
# {'sentence': "There are entities who lock down their network to the point that there's no npm and therefore no build tools.", 'predicate': [{'str': 'are', 'lemma': 'be', 'POS': 'VERB'}], 'clause': "entities who lock down their network to the point that there's no npm and therefore no build tools", 'type': 'constituent'}
# {'sentence': "I don't use this approach because it little bit weird to me - all stuff in one big file, like PHP did before.", 'predicate': [{'str': 'use', 'lemma': 'use', 'POS': 'VERB'}], 'clause': 'this approach because it little bit weird to me - all stuff in one big file, like PHP did before', 'type': 'declarative'}
# {'sentence': 'But you still need to use Babel and Rollup even if you need to run this code in NodeJS', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to run this code in NodeJS', 'type': 'declarative'}
# {'sentence': 'This course is for students that are not able to stay for long periods in Spain, and need to improve their Spanish in a short span of time', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to improve their Spanish in a short span of time', 'type': 'declarative'}
# {'sentence': 'If you would like to take an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs.', 'predicate': [{'str': 'like', 'lemma': 'like', 'POS': 'VERB'}], 'clause': 'to take an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs', 'type': 'declarative'}
# {'sentence': 'If you would like to take an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs.', 'predicate': [{'str': 'take', 'lemma': 'take', 'POS': 'VERB'}], 'clause': 'an intensive course and are able to stay for a three month period, take a look at the Intensive Semester programs', 'type': 'declarative'}
# {'sentence': 'If I don’t have any inspiration I won’t create and I need to create as an outlet', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to create as an outlet', 'type': 'declarative'}
# {'sentence': 'Clearing my mind and my physical space is important', 'predicate': [{'str': 'Clearing', 'lemma': 'clear', 'POS': 'VERB'}], 'clause': 'my mind and my physical space is important', 'type': 'declarative'}
# {'sentence': 'Usually before I can get creative I organize my space and I also need to be able to relax', 'predicate': [{'str': 'get', 'lemma': 'get', 'POS': 'VERB'}], 'clause': 'creative I organize my space and I also need to be able to relax', 'type': 'declarative'}
# {'sentence': 'Usually before I can get creative I organize my space and I also need to be able to relax', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to be able to relax', 'type': 'declarative'}
# {'sentence': 'This is sometimes difficult to find an experience that truly fuels and nurtures', 'predicate': [{'str': 'fuels', 'lemma': 'fuel', 'POS': 'VERB'}], 'clause': 'and nurtures', 'type': 'declarative'}
# {'sentence': 'Listening to a song, or seeing a photograph or reading an article can be inspirational at times', 'predicate': [{'str': 'seeing', 'lemma': 'see', 'POS': 'VERB'}], 'clause': 'a photograph or reading an article can be inspirational at times', 'type': 'declarative'}
# {'sentence': 'I’d like to learn more ways so inspiration can be controlled.', 'predicate': [{'str': 'learn', 'lemma': 'learn', 'POS': 'VERB'}], 'clause': 'more ways so inspiration can be controlled', 'type': 'declarative'}
# {'sentence': 'The fact is, not everyone intends to be your Facebook friend', 'predicate': [{'str': 'intends', 'lemma': 'intend', 'POS': 'VERB'}], 'clause': 'to be your Facebook friend', 'type': 'declarative'}
# {'sentence': 'Everyone makes use of Facebook in different ways, some approve good friend requests from everyone, others wish to keep job and residence life different, while some people just disregard requests completely.', 'predicate': [{'str': 'wish', 'lemma': 'wish', 'POS': 'VERB'}], 'clause': 'to keep job and residence life different, while some people just disregard requests completely', 'type': 'declarative'}
# {'sentence': 'Exhibits in Landscapes of Life include an immersive audio-visual theatre showing personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field.', 'predicate': [{'str': 'include', 'lemma': 'include', 'POS': 'VERB'}], 'clause': 'an immersive audio-visual theatre showing personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field', 'type': 'constituent'}
# {'sentence': 'Exhibits in Landscapes of Life include an immersive audio-visual theatre showing personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field.', 'predicate': [{'str': 'showing', 'lemma': 'show', 'POS': 'VERB'}], 'clause': 'personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field', 'type': 'constituent'}
# {'sentence': 'Exhibits in Landscapes of Life include an immersive audio-visual theatre showing personal stories of remembrance, a history of remembrance timeline, with examples from the Bronze Age to the present day; and interactives, for visitors of all ages, including a memory booth where visitors can record their own stories and a digital poppy field.', 'predicate': [{'str': 'including', 'lemma': 'include', 'POS': 'VERB'}], 'clause': 'a memory booth where visitors can record their own stories and a digital poppy field', 'type': 'constituent'}
# {'sentence': 'Included in the entry price for the exhibition is access to the Arboretum’s temporary exhibition gallery and an audio guide which can be used to explore and learn about 93 of the memorials across the Arboretum site.', 'predicate': [{'str': 'Included', 'lemma': 'include', 'POS': 'VERB'}, {'str': 'in', 'lemma': 'in', 'POS': 'ADP'}], 'clause': 'the entry price for the exhibition is access to the Arboretum’s temporary exhibition gallery and an audio guide which can be used to explore and learn about 93 of the memorials across the Arboretum site', 'type': 'constituent'}
# {'sentence': 'Included in the entry price for the exhibition is access to the Arboretum’s temporary exhibition gallery and an audio guide which can be used to explore and learn about 93 of the memorials across the Arboretum site.', 'predicate': [{'str': 'explore', 'lemma': 'explore', 'POS': 'VERB'}], 'clause': 'and learn about 93 of the memorials across the Arboretum site', 'type': 'declarative'}
# {'sentence': 'When would you like to stay at HotelHome Paris 16?', 'predicate': [{'str': 'like', 'lemma': 'like', 'POS': 'VERB'}], 'clause': 'to stay at HotelHome Paris 16', 'type': 'declarative'}
# {'sentence': 'We chose to buy thisapart-hotel in 2002 because we like to welcome and receive our guests not only as customers but as friends', 'predicate': [{'str': 'welcome', 'lemma': 'welcome', 'POS': 'VERB'}], 'clause': 'and receive our guests not only as customers but as friends', 'type': 'declarative'}
# {'sentence': 'We love to make their stay pleasant and comfortable in a very friendly atmosphere', 'predicate': [{'str': 'make', 'lemma': 'make', 'POS': 'VERB'}], 'clause': 'their stay pleasant and comfortable in a very friendly atmosphere', 'type': 'declarative'}
# {'sentence': 'Choosing HotelHome Paris 16 is choosing a helpful staff, unique apartments, and a team at your service', 'predicate': [{'str': 'Choosing', 'lemma': 'choose', 'POS': 'VERB'}], 'clause': 'HotelHome Paris 16 is choosing a helpful staff, unique apartments, and a team at your service', 'type': 'declarative'}
# {'sentence': 'If you plan to arrive later than 18:00 or on a weekend, please contact the hotel in advance to obtain the main door access code.', 'predicate': [{'str': 'contact', 'lemma': 'contact', 'POS': 'VERB'}], 'clause': 'the hotel in advance to obtain the main door access code', 'type': 'declarative'}
# {'sentence': 'The lift is to small, so it takes time to bring the luggage to the 5th fl.', 'predicate': [{'str': 'takes', 'lemma': 'take', 'POS': 'VERB'}], 'clause': 'time to bring the luggage to the 5th fl', 'type': 'declarative'}
# {'sentence': 'Beds need to be renewed because they are noisy and uncomfortable.', 'predicate': [{'str': 'need', 'lemma': 'need', 'POS': 'VERB'}], 'clause': 'to be renewed because they are noisy and uncomfortable', 'type': 'declarative'}

# %%
#stats for evaluating baseline against golden set - detection

#get predicate lists for sentences
def get_preds(annotations):
  preds = dict.fromkeys(gold_sentences, [])
  for a in annotations:
    sentence = a['sentence']
    predicate = a['predicate']
    if preds[sentence] == []:
      preds[sentence] = [predicate]
    else:
      preds[sentence] += [predicate]
  return preds

preds_gold = get_preds(gold_annotations)
preds_baseline = get_preds(baseline_results)

#print(preds_gold)
#print(preds_baseline)

#get f1
def get_f1(tp, fp, fn):
  precision = tp/(tp+fp)
  recall = tp/(tp+fn)
  f1 = (2*precision*recall)/(precision + recall)
  return [precision, recall, f1]

#detection - single clause
tp = 0
fp = 0
fn = 0

for s in gold_sentences:
  gp = preds_gold[s]
  bp = preds_baseline[s]

  if len(gp) != 1:
    continue

  if len(gp) == len(bp):
    tp += len(gp)
  elif len(gp) > len(bp):
    fn += len(gp) - len(bp)
    tp += len(bp)
  elif len(gp) < len(bp):
    fp += len(bp) - len(gp)
    tp += len(gp)

print("---------Embedded Clause Detection, Single Clause F1---------")
print("True Positives: ", tp, "\nFalse Positives: ", fp, "\nFalse Negatives: ", fn)
print("Precision, Recall, F1: ", get_f1(tp, fp, fn))
print("Accuracy: ", (tp/(tp+fp+fn)))
print()

#detection - multiple clause
tp = 0
fp = 0
fn = 0

for s in gold_sentences:
  gp = preds_gold[s]
  bp = preds_baseline[s]

  if len(gp) == 1:
    continue

  if len(gp) == len(bp):
    tp += len(gp)
  elif len(gp) > len(bp):
    fn += len(gp) - len(bp)
    tp += len(bp)
  elif len(gp) < len(bp):
    fp += len(bp) - len(gp)
    tp += len(gp)

print("---------Embedded Clause Detection, Multi Clause F1---------")
print("True Positives: ", tp, "\nFalse Positives: ", fp, "\nFalse Negatives: ", fn)
print("Precision, Recall, F1: ", get_f1(tp, fp, fn))
print("Accuracy: ", (tp/(tp+fp+fn)))
print()

#detection - overall
tp = 0
tn = len(advers_sentences) - len(baseline_advers)
fp = len(baseline_advers)
fn = 0

for s in gold_sentences:
  gp = preds_gold[s]
  bp = preds_baseline[s]

  if len(gp) == len(bp):
    tp += len(gp)
  elif len(gp) > len(bp):
    fn += len(gp) - len(bp)
    tp += len(bp)
  elif len(gp) < len(bp):
    fp += len(bp) - len(gp)
    tp += len(gp)

print("---------Embedded Clause Detection, Overall F1---------")
print("True Positives: ", tp, "\nTrue Negatives", tn, "\nFalse Positives: ", fp, "\nFalse Negatives: ", fn)
print("Precision, Recall, F1: ", get_f1(tp, fp, fn))
print("Accuracy: ", ((tp+tn)/(tp+tn+fp+fn)))
print()
# Out:
# ---------Embedded Clause Detection, Single Clause F1---------
# True Positives:  354
# False Positives:  297
# False Negatives:  24
# Precision, Recall, F1:  [0.543778801843318, 0.9365079365079365, 0.6880466472303207]
# Accuracy:  0.5244444444444445
#
# ---------Embedded Clause Detection, Multi Clause F1---------
# True Positives:  127
# False Positives:  47
# False Negatives:  22
# Precision, Recall, F1:  [0.7298850574712644, 0.8523489932885906, 0.7863777089783281]
# Accuracy:  0.6479591836734694
#
# ---------Embedded Clause Detection, Overall F1---------
# True Positives:  481
# True Negatives 44
# False Positives:  411
# False Negatives:  46
# Precision, Recall, F1:  [0.5392376681614349, 0.9127134724857685, 0.6779422128259337]
# Accuracy:  0.5346232179226069

# %%
#stats for evaluating baseline against golden set - accuracy

gold_per_sent = dict.fromkeys(gold_sentences, [])
for g in gold_annotations:
  if gold_per_sent[g['sentence']] == []:
    gold_per_sent[g['sentence']] = [g]
  else:
    gold_per_sent[g['sentence']] += [g]

base_per_sent = dict.fromkeys(gold_sentences, [])
for g in baseline_results:
  if base_per_sent[g['sentence']] == []:
    base_per_sent[g['sentence']] = [g]
  else:
    base_per_sent[g['sentence']] += [g]

def get_counts(my_list):
  my_list = [str(item) for item in my_list]
  counts = dict.fromkeys(my_list, 0)
  for item in my_list:
    counts[item] += 1
  return counts

#predicate identification
true_preds = 0
for b in gold_sentences:
  golds = gold_per_sent[b]
  base = base_per_sent[b]
  gpred = ["".join([gg['lemma'] for gg in g['predicate']]) for g in golds]
  bpred = ["".join([bb['lemma'] for bb in b['predicate']]) for b in base]
  gfreq = get_counts(gpred)
  bfreq = get_counts(bpred)
  for key in gfreq:
    if key in bfreq:
      if gfreq[key] == bfreq[key]:
        true_preds += gfreq[key]
      elif gfreq[key] > bfreq[key]:
        true_preds += bfreq[key]
      else:
        true_preds += gfreq[key]

print("---------Embedding Predicate Accuracy---------")
print(true_preds/tp)
print()

#clause identification
true_clause = 0
for b in gold_sentences:
  golds = gold_per_sent[b]
  base = base_per_sent[b]
  gclause = [g['clause'] for g in golds]
  bclause = [b['clause'] for b in base]
  gfreq = get_counts(gclause)
  bfreq = get_counts(bclause)
  for key in gfreq:
    if key in bfreq:
      if gfreq[key] == bfreq[key]:
        true_clause += gfreq[key]
      elif gfreq[key] > bfreq[key]:
        true_clause += bfreq[key]
      else:
        true_clause += gfreq[key]

print("---------Embedded Clause Accuracy---------")
print(true_clause/tp)
print()

#typing
true_type = 0
for b in gold_sentences:
  golds = gold_per_sent[b]
  base = base_per_sent[b]
  gtype = [g['type'] for g in golds]
  btype = [b['type'] for b in base]
  gfreq = get_counts(gtype)
  bfreq = get_counts(btype)
  for key in gfreq:
    if key in bfreq:
      if gfreq[key] == bfreq[key]:
        true_type += gfreq[key]
      elif gfreq[key] > bfreq[key]:
        true_type += bfreq[key]
      else:
        true_type += gfreq[key]

print("---------Embedded Clause Type Accuracy---------")
print(true_type/tp)
print()
# Out:
# ---------Embedding Predicate Accuracy---------
# 0.7941787941787942
#
# ---------Embedded Clause Accuracy---------
# 0.4968814968814969
#
# ---------Embedded Clause Type Accuracy---------
# 0.9355509355509356
